# %%
# Try reading the problematic file with 'python' engine
file_path = "/mnt/data/SoilGrids_Extracted/Far South.csv"

try:
    df = pd.read_csv(file_path, engine="python")  # Use Python engine to handle irregularities
    print("\n✅ Successfully loaded Far South.csv using 'python' engine.")
except Exception as e:
    print(f"❌ Still cannot read Far South.csv: {e}")
# Out:
# ❌ Still cannot read Far South.csv: [Errno 2] No such file or directory: '/mnt/data/SoilGrids_Extracted/Far South.csv'

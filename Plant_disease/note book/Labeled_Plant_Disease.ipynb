# %%
# !apt-get install unrar
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unrar is already the newest version (1:6.1.5-1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# !unzip "/content/Casva_leaf disease Identify.v2i.yolov8.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/labels/Manioc_Mosaique-822-_jpg.rf.35f1687d8a5a41b6ffe23a6816dc65ac.txt
#  extracting: train/labels/Manioc_Mosaique-822-_jpg.rf.a0401f2bb881ac98978fcdc0ce6ddb35.txt
#   inflating: train/labels/Manioc_Mosaique-822-_jpg.rf.ec95f840a9a547c72a208d5323c00886.txt
#   inflating: train/labels/Manioc_Mosaique-823-_jpg.rf.24c6b6d634bc02a11f27f57cdd2608fd.txt
#   inflating: train/labels/Manioc_Mosaique-823-_jpg.rf.a923216892629854bf2a28e67f76dfe5.txt
#   inflating: train/labels/Manioc_Mosaique-823-_jpg.rf.e2715916f2a38bcc1493432004487406.txt
#   inflating: train/labels/Manioc_Mosaique-824-_jpg.rf.0e4ae2e1b100ccee37ec2cf0fe5fd0ad.txt
#   inflating: train/labels/Manioc_Mosaique-824-_jpg.rf.1de1447c100a111556a8abd330e590fb.txt
#   inflating: train/labels/Manioc_Mosaique-824-_jpg.rf.a684df6ec8340433b6246fc4f068b874.txt
#   inflating: train/labels/Manioc_Mosaique-826-_jpg.rf.90b08b4ce7eef9d143eb56c0508cf70b.txt
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 911.4/911.4 kB 15.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # YOLOv8 nano modelch
model.train(data='/content/data.yaml', epochs=20, imgsz=640)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 60.1MB/s]
# Ultralytics 8.3.66 🚀 Python-3.11.11 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !zip -r project_results.zip /content/runs

# %%
from google.colab import files
files.download("project_results.zip")

# %%
files.download("/content/yolov8n.pt")

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp -r /content/runs /content/drive/MyDrive/

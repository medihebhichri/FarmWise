# %%
# Import necessary libraries
import os
import pandas as pd
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Define paths
DATA_PATH = "/content/drive/My Drive/FarmWise/Cleaned_Data/FAO"
PROCESSED_PATH = "/content/drive/My Drive/FarmWise/Processed_Data/FAO"
os.makedirs(PROCESSED_PATH, exist_ok=True)

# Gather all dataset files (CSV format)
data_files = []
for root, _, files in os.walk(DATA_PATH):
    for file in files:
        if file.endswith(".csv"):
            data_files.append(os.path.join(root, file))

print(f"\n Found {len(data_files)} datasets across subfolders:")
for file in data_files:
    print(f"   - {file}")

# Function to process datasets
def process_dataset(file_path):
    try:
        # Load dataset
        df = pd.read_csv(file_path)

        print(f"\n🔍 Processing: {file_path}")
        print(df.info())  # Display dataset structure
        print(df.head())  # Preview first few rows

        # Drop duplicates
        df = df.drop_duplicates()

        # Handle missing values (Modify as needed)
        df = df.fillna(method='ffill')  # Forward fill missing values

        # Standardize column names (lowercase, remove spaces, replace special characters)
        df.columns = df.columns.str.lower().str.replace(" ", "_").str.replace("[^a-zA-Z0-9_]", "", regex=True)

        # Maintain original subfolder structure
        relative_path = os.path.relpath(file_path, DATA_PATH)
        processed_file_path = os.path.join(PROCESSED_PATH, relative_path)

        # Ensure subdirectories exist before saving
        os.makedirs(os.path.dirname(processed_file_path), exist_ok=True)
        df.to_csv(processed_file_path, index=False)

        print(f" ✅ Processed dataset saved: {processed_file_path}")

    except Exception as e:
        print(f" ❌ Error processing {file_path}: {e}")

# Process all datasets
for file in data_files:
    process_dataset(file)

print("\n ✅ All datasets (including subfolders) have been processed and saved!")
# Out:
# Mounted at /content/drive
#
#  Found 26 datasets across subfolders:
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Production/Production Indices.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Production/Crops and livestock products.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Production/Value of Agricultural Production.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Climate Change-Agrifood systems emissions/Land use and change/Emissions from Drained organic soils.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Climate Change-Agrifood systems emissions/Totals and Indicators/Emissions totals.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Climate Change-Agrifood systems emissions/Totals and Indicators/Emissions indicators.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Climate Change-Agrifood systems emissions/Totals and Indicators/Emissions intensities.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Climate Change-Agrifood systems emissions/Farm gate/Emissions from Crops.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Climate Change-Agrifood systems emissions/Farm gate/Emissions from Livestock.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Climate Change-Agrifood systems emissions/Farm gate/Emissions from Energy use in agriculture.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Population and employment/Employment indicators/Employment Indicators-Agriculture and agrifood systems.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Population and employment/Employment indicators/Employment Indicators-Rural.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Discontinued archives and data series/Machinery.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Trade/Crops and livestock products indicators.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Trade/Crops and livestock products.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Land, Inputs and Sustainability/Climate change indicators/Temperature change on land.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Land, Inputs and Sustainability/Inputs/Fertilizers by Product.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Land, Inputs and Sustainability/Inputs/Livestock Manure.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Land, Inputs and Sustainability/Sustainability indicators/Livestock Patterns.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Land, Inputs and Sustainability/Sustainability indicators/Cropland Nutrient Balance.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Land, Inputs and Sustainability/Land/Land Use.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Land, Inputs and Sustainability/Land/Land Cover.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Land, Inputs and Sustainability/Land/Fertilizers by Nutrient.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/World Census of Agriculture/Structural data from agricultural censuses.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Investment/Credit to Agriculture.csv
#    - /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Investment/Development Flows to Agriculture.csv
#
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Production/Production Indices.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11926 entries, 0 to 11925
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       11926 non-null  object
#  1   domain            11926 non-null  object
#  2   area_code_m49     11926 non-null  int64
#  3   area              11926 non-null  object
#  4   element_code      11926 non-null  int64
#  5   element           11926 non-null  object
#  6   item_code_cpc     11926 non-null  object
#  7   item              11926 non-null  object
#  8   year_code         11926 non-null  int64
#  9   year              11926 non-null  int64
#  10  value             11926 non-null  float64
#  11  flag              11926 non-null  object
#  12  flag_description  11926 non-null  object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.2+ MB
# None
#   domain_code              domain  area_code_m49     area  element_code  \
# 0          QI  Production Indices            788  Tunisia           432
# 1          QI  Production Indices            788  Tunisia           432
# 2          QI  Production Indices            788  Tunisia           432
# 3          QI  Production Indices            788  Tunisia           432
# 4          QI  Production Indices            788  Tunisia           432
#
#                                            element item_code_cpc  \
# 0  Gross Production Index Number (2014-2016 = 100)         01371
# 1  Gross Production Index Number (2014-2016 = 100)         01371
# 2  Gross Production Index Number (2014-2016 = 100)         01371
# 3  Gross Production Index Number (2014-2016 = 100)         01371
# 4  Gross Production Index Number (2014-2016 = 100)         01371
#
#                 item  year_code  year  value flag flag_description
# 0  Almonds, in shell       1961  1961   8.77    E  Estimated value
# 1  Almonds, in shell       1962  1962  10.13    E  Estimated value
# 2  Almonds, in shell       1963  1963   8.77    E  Estimated value
# 3  Almonds, in shell       1964  1964  10.73    E  Estimated value
# 4  Almonds, in shell       1965  1965  12.09    E  Estimated value
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Production/Production Indices.csv
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Production/Crops and livestock products.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23330 entries, 0 to 23329
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       23330 non-null  object
#  1   domain            23330 non-null  object
#  2   area_code_m49     23330 non-null  int64
#  3   area              23330 non-null  object
#  4   element_code      23330 non-null  int64
#  5   element           23330 non-null  object
#  6   item_code_cpc     23330 non-null  object
#  7   item              23330 non-null  object
#  8   year_code         23330 non-null  int64
#  9   year              23330 non-null  int64
#  10  unit              23330 non-null  object
#  11  value             23330 non-null  float64
#  12  flag              23330 non-null  object
#  13  flag_description  23330 non-null  object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 2.5+ MB
# None
#   domain_code                        domain  area_code_m49     area  \
# 0         QCL  Crops and livestock products            788  Tunisia
# 1         QCL  Crops and livestock products            788  Tunisia
# 2         QCL  Crops and livestock products            788  Tunisia
# 3         QCL  Crops and livestock products            788  Tunisia
# 4         QCL  Crops and livestock products            788  Tunisia
#
#    element_code         element item_code_cpc               item  year_code  \
# 0          5312  Area harvested         01371  Almonds, in shell       1961
# 1          5412           Yield         01371  Almonds, in shell       1961
# 2          5510      Production         01371  Almonds, in shell       1961
# 3          5312  Area harvested         01371  Almonds, in shell       1962
# 4          5412           Yield         01371  Almonds, in shell       1962
#
#    year   unit    value flag flag_description
# 0  1961     ha  85000.0    E  Estimated value
# 1  1961  kg/ha     68.2    E  Estimated value
# 2  1961      t   5800.0    A  Official figure
# 3  1962     ha  98000.0    E  Estimated value
# 4  1962  kg/ha     68.4    E  Estimated value
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Production/Crops and livestock products.csv
#
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Production/Value of Agricultural Production.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18325 entries, 0 to 18324
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       18325 non-null  object
#  1   domain            18325 non-null  object
#  2   area_code_m49     18325 non-null  int64
#  3   area              18325 non-null  object
#  4   element_code      18325 non-null  int64
#  5   element           18325 non-null  object
#  6   item_code_cpc     18325 non-null  object
#  7   item              18325 non-null  object
#  8   year_code         18325 non-null  int64
#  9   year              18325 non-null  int64
#  10  unit              18325 non-null  object
#  11  value             18325 non-null  int64
#  12  flag              18325 non-null  object
#  13  flag_description  18325 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 2.0+ MB
# None
#   domain_code                            domain  area_code_m49     area  \
# 0          QV  Value of Agricultural Production            788  Tunisia
# 1          QV  Value of Agricultural Production            788  Tunisia
# 2          QV  Value of Agricultural Production            788  Tunisia
# 3          QV  Value of Agricultural Production            788  Tunisia
# 4          QV  Value of Agricultural Production            788  Tunisia
#
#    element_code                                            element  \
# 0           152  Gross Production Value (constant 2014-2016 tho...
# 1           152  Gross Production Value (constant 2014-2016 tho...
# 2           152  Gross Production Value (constant 2014-2016 tho...
# 3           152  Gross Production Value (constant 2014-2016 tho...
# 4           152  Gross Production Value (constant 2014-2016 tho...
#
#   item_code_cpc               item  year_code  year       unit  value flag  \
# 0         01371  Almonds, in shell       1961  1961  1000 Int$  29325    E
# 1         01371  Almonds, in shell       1962  1962  1000 Int$  33876    E
# 2         01371  Almonds, in shell       1963  1963  1000 Int$  29325    E
# 3         01371  Almonds, in shell       1964  1964  1000 Int$  35898    E
# 4         01371  Almonds, in shell       1965  1965  1000 Int$  40449    E
#
#   flag_description
# 0  Estimated value
# 1  Estimated value
# 2  Estimated value
# 3  Estimated value
# 4  Estimated value
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Production/Value of Agricultural Production.csv
#
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Climate Change-Agrifood systems emissions/Land use and change/Emissions from Drained organic soils.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       306 non-null    object
#  1   domain            306 non-null    object
#  2   area_code_m49     306 non-null    int64
#  3   area              306 non-null    object
#  4   element_code      306 non-null    int64
#  5   element           306 non-null    object
#  6   item_code         306 non-null    int64
#  7   item              306 non-null    object
#  8   year_code         306 non-null    int64
#  9   year              306 non-null    int64
#  10  source_code       306 non-null    int64
#  11  source            306 non-null    object
#  12  unit              306 non-null    object
#  13  value             306 non-null    int64
#  14  flag              306 non-null    object
#  15  flag_description  306 non-null    object
# dtypes: int64(7), object(9)
# memory usage: 38.4+ KB
# None
#   domain_code                                domain  area_code_m49     area  \
# 0          GV  Emissions from Drained organic soils            788  Tunisia
# 1          GV  Emissions from Drained organic soils            788  Tunisia
# 2          GV  Emissions from Drained organic soils            788  Tunisia
# 3          GV  Emissions from Drained organic soils            788  Tunisia
# 4          GV  Emissions from Drained organic soils            788  Tunisia
#
#    element_code          element  item_code                    item  \
# 0          5026             Area       6727  Cropland organic soils
# 1          7230  Emissions (N2O)       6727  Cropland organic soils
# 2          7273  Emissions (CO2)       6727  Cropland organic soils
# 3          5026             Area       6727  Cropland organic soils
# 4          7230  Emissions (N2O)       6727  Cropland organic soils
#
#    year_code  year  source_code      source unit  value flag flag_description
# 0       1990  1990         3050  FAO TIER 1   ha      0    E  Estimated value
# 1       1990  1990         3050  FAO TIER 1   kt      0    E  Estimated value
# 2       1990  1990         3050  FAO TIER 1   kt      0    E  Estimated value
# 3       1991  1991         3050  FAO TIER 1   ha      0    E  Estimated value
# 4       1991  1991         3050  FAO TIER 1   kt      0    E  Estimated value
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Climate Change-Agrifood systems emissions/Land use and change/Emissions from Drained organic soils.csv
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Climate Change-Agrifood systems emissions/Totals and Indicators/Emissions totals.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9499 entries, 0 to 9498
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       9499 non-null   object
#  1   domain            9499 non-null   object
#  2   area_code_m49     9499 non-null   int64
#  3   area              9499 non-null   object
#  4   element_code      9499 non-null   int64
#  5   element           9499 non-null   object
#  6   item_code         9499 non-null   int64
#  7   item              9499 non-null   object
#  8   year_code         9499 non-null   int64
#  9   year              9499 non-null   int64
#  10  source_code       9499 non-null   int64
#  11  source            9499 non-null   object
#  12  unit              9499 non-null   object
#  13  value             9499 non-null   float64
#  14  flag              9499 non-null   object
#  15  flag_description  9499 non-null   object
# dtypes: float64(1), int64(6), object(9)
# memory usage: 1.2+ MB
# None
#   domain_code            domain  area_code_m49     area  element_code  \
# 0          GT  Emissions totals            788  Tunisia          7234
# 1          GT  Emissions totals            788  Tunisia          7236
# 2          GT  Emissions totals            788  Tunisia          7230
# 3          GT  Emissions totals            788  Tunisia        724313
# 4          GT  Emissions totals            788  Tunisia        723113
#
#                             element  item_code           item  year_code  \
# 0            Direct emissions (N2O)       5064  Crop Residues       1961
# 1          Indirect emissions (N2O)       5064  Crop Residues       1961
# 2                   Emissions (N2O)       5064  Crop Residues       1961
# 3  Emissions (CO2eq) from N2O (AR5)       5064  Crop Residues       1961
# 4           Emissions (CO2eq) (AR5)       5064  Crop Residues       1961
#
#    year  source_code      source unit    value flag flag_description
# 0  1961         3050  FAO TIER 1   kt   0.1743    E  Estimated value
# 1  1961         3050  FAO TIER 1   kt   0.0392    E  Estimated value
# 2  1961         3050  FAO TIER 1   kt   0.2135    E  Estimated value
# 3  1961         3050  FAO TIER 1   kt  56.5775    E  Estimated value
# 4  1961         3050  FAO TIER 1   kt  56.5775    E  Estimated value
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Climate Change-Agrifood systems emissions/Totals and Indicators/Emissions totals.csv
#
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Climate Change-Agrifood systems emissions/Totals and Indicators/Emissions indicators.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2805 entries, 0 to 2804
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       2805 non-null   object
#  1   domain            2805 non-null   object
#  2   area_code_m49     2805 non-null   int64
#  3   area              2805 non-null   object
#  4   element_code      2805 non-null   int64
#  5   element           2805 non-null   object
#  6   item_code         2805 non-null   int64
#  7   item              2805 non-null   object
#  8   year_code         2805 non-null   int64
#  9   year              2805 non-null   int64
#  10  unit              2805 non-null   object
#  11  value             2805 non-null   float64
#  12  flag              2805 non-null   object
#  13  flag_description  2805 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 306.9+ KB
# None
#   domain_code                domain  area_code_m49     area  element_code  \
# 0          EM  Emissions indicators            788  Tunisia        726313
# 1          EM  Emissions indicators            788  Tunisia        726313
# 2          EM  Emissions indicators            788  Tunisia        726313
# 3          EM  Emissions indicators            788  Tunisia        726313
# 4          EM  Emissions indicators            788  Tunisia        726313
#
#                          element  item_code       item  year_code  year unit  \
# 0  Emissions Share (CO2eq) (AR5)       6996  Farm gate       1990  1990    %
# 1  Emissions Share (CO2eq) (AR5)       6996  Farm gate       1991  1991    %
# 2  Emissions Share (CO2eq) (AR5)       6996  Farm gate       1992  1992    %
# 3  Emissions Share (CO2eq) (AR5)       6996  Farm gate       1993  1993    %
# 4  Emissions Share (CO2eq) (AR5)       6996  Farm gate       1994  1994    %
#
#    value flag flag_description
# 0  20.99    E  Estimated value
# 1  20.09    E  Estimated value
# 2  20.75    E  Estimated value
# 3  21.03    E  Estimated value
# 4  20.62    E  Estimated value
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Climate Change-Agrifood systems emissions/Totals and Indicators/Emissions indicators.csv
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Climate Change-Agrifood systems emissions/Totals and Indicators/Emissions intensities.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2108 entries, 0 to 2107
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       2108 non-null   object
#  1   domain            2108 non-null   object
#  2   area_code_m49     2108 non-null   int64
#  3   area              2108 non-null   object
#  4   element_code      2108 non-null   int64
#  5   element           2108 non-null   object
#  6   item_code_cpc     2108 non-null   object
#  7   item              2108 non-null   object
#  8   year_code         2108 non-null   int64
#  9   year              2108 non-null   int64
#  10  unit              2108 non-null   object
#  11  value             2108 non-null   float64
#  12  flag              2108 non-null   object
#  13  flag_description  2108 non-null   object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 230.7+ KB
# None
#   domain_code                 domain  area_code_m49     area  element_code  \
# 0          EI  Emissions intensities            788  Tunisia         71761
# 1          EI  Emissions intensities            788  Tunisia         71761
# 2          EI  Emissions intensities            788  Tunisia         71761
# 3          EI  Emissions intensities            788  Tunisia         71761
# 4          EI  Emissions intensities            788  Tunisia         71761
#
#                element item_code_cpc                    item  year_code  year  \
# 0  Emissions intensity         F1718  Cereals excluding rice       1961  1961
# 1  Emissions intensity         F1718  Cereals excluding rice       1962  1962
# 2  Emissions intensity         F1718  Cereals excluding rice       1963  1963
# 3  Emissions intensity         F1718  Cereals excluding rice       1964  1964
# 4  Emissions intensity         F1718  Cereals excluding rice       1965  1965
#
#           unit   value flag flag_description
# 0  kg CO2eq/kg  0.1724    E  Estimated value
# 1  kg CO2eq/kg  0.1374    E  Estimated value
# 2  kg CO2eq/kg  0.1313    E  Estimated value
# 3  kg CO2eq/kg  0.1478    E  Estimated value
# 4  kg CO2eq/kg  0.1370    E  Estimated value
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Climate Change-Agrifood systems emissions/Totals and Indicators/Emissions intensities.csv
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Climate Change-Agrifood systems emissions/Farm gate/Emissions from Crops.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2652 entries, 0 to 2651
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       2652 non-null   object
#  1   domain            2652 non-null   object
#  2   area_code_m49     2652 non-null   int64
#  3   area              2652 non-null   object
#  4   element_code      2652 non-null   int64
#  5   element           2652 non-null   object
#  6   item_code_cpc     2652 non-null   object
#  7   item              2652 non-null   object
#  8   year_code         2652 non-null   int64
#  9   year              2652 non-null   int64
#  10  source_code       2652 non-null   int64
#  11  source            2652 non-null   object
#  12  unit              2652 non-null   object
#  13  value             2652 non-null   float64
#  14  flag              2652 non-null   object
#  15  flag_description  2652 non-null   object
# dtypes: float64(1), int64(5), object(10)
# memory usage: 331.6+ KB
# None
#   domain_code                domain  area_code_m49     area  element_code  \
# 0         GCE  Emissions from Crops            788  Tunisia         72392
# 1         GCE  Emissions from Crops            788  Tunisia         72302
# 2         GCE  Emissions from Crops            788  Tunisia         72342
# 3         GCE  Emissions from Crops            788  Tunisia         72362
# 4         GCE  Emissions from Crops            788  Tunisia         72392
#
#                                   element item_code_cpc    item  year_code  \
# 0               Crop residues (N content)          0115  Barley       1961
# 1           Crop residues (Emissions N2O)          0115  Barley       1961
# 2    Crop residues (Direct emissions N2O)          0115  Barley       1961
# 3  Crop residues (Indirect emissions N2O)          0115  Barley       1961
# 4               Crop residues (N content)          0115  Barley       1962
#
#    year  source_code      source unit         value flag flag_description
# 0  1961         3050  FAO TIER 1   kg  1.837008e+06    E  Estimated value
# 1  1961         3050  FAO TIER 1   kt  3.540000e-02    E  Estimated value
# 2  1961         3050  FAO TIER 1   kt  2.890000e-02    E  Estimated value
# 3  1961         3050  FAO TIER 1   kt  6.500000e-03    E  Estimated value
# 4  1962         3050  FAO TIER 1   kg  2.906355e+06    E  Estimated value
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Climate Change-Agrifood systems emissions/Farm gate/Emissions from Crops.csv
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Climate Change-Agrifood systems emissions/Farm gate/Emissions from Livestock.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32167 entries, 0 to 32166
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       32167 non-null  object
#  1   domain            32167 non-null  object
#  2   area_code_m49     32167 non-null  int64
#  3   area              32167 non-null  object
#  4   element_code      32167 non-null  int64
#  5   element           32167 non-null  object
#  6   item_code_cpc     32167 non-null  object
#  7   item              32167 non-null  object
#  8   year_code         32167 non-null  int64
#  9   year              32167 non-null  int64
#  10  source_code       32167 non-null  int64
#  11  source            32167 non-null  object
#  12  unit              32167 non-null  object
#  13  value             32167 non-null  float64
#  14  flag              32167 non-null  object
#  15  flag_description  32167 non-null  object
# dtypes: float64(1), int64(5), object(10)
# memory usage: 3.9+ MB
# None
#   domain_code                    domain  area_code_m49     area  element_code  \
# 0         GLE  Emissions from Livestock            788  Tunisia          5111
# 1         GLE  Emissions from Livestock            788  Tunisia         72431
# 2         GLE  Emissions from Livestock            788  Tunisia         72441
# 3         GLE  Emissions from Livestock            788  Tunisia         72254
# 4         GLE  Emissions from Livestock            788  Tunisia         72386
#
#                                          element item_code_cpc   item  \
# 0                                         Stocks         02132  Asses
# 1                Livestock total (Emissions N2O)         02132  Asses
# 2                Livestock total (Emissions CH4)         02132  Asses
# 3           Enteric fermentation (Emissions CH4)         02132  Asses
# 4  Manure management (manure treated, N content)         02132  Asses
#
#    year_code  year  source_code      source unit        value flag  \
# 0       1961  1961         3050  FAO TIER 1   An  180000.0000    A
# 1       1961  1961         3050  FAO TIER 1   kt       0.0892    E
# 2       1961  1961         3050  FAO TIER 1   kt       1.9620    E
# 3       1961  1961         3050  FAO TIER 1   kt       1.8000    E
# 4       1961  1961         3050  FAO TIER 1   kg   78577.2000    E
#
#   flag_description
# 0  Official figure
# 1  Estimated value
# 2  Estimated value
# 3  Estimated value
# 4  Estimated value
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Climate Change-Agrifood systems emissions/Farm gate/Emissions from Livestock.csv
#
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Climate Change-Agrifood systems emissions/Farm gate/Emissions from Energy use in agriculture.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       660 non-null    object
#  1   domain            660 non-null    object
#  2   area_code_m49     660 non-null    int64
#  3   area              660 non-null    object
#  4   element_code      660 non-null    int64
#  5   element           660 non-null    object
#  6   item_code         660 non-null    int64
#  7   item              660 non-null    object
#  8   year_code         660 non-null    int64
#  9   year              660 non-null    int64
#  10  unit              660 non-null    object
#  11  value             660 non-null    float64
#  12  flag              660 non-null    object
#  13  flag_description  660 non-null    object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 72.3+ KB
# None
#   domain_code                                    domain  area_code_m49  \
# 0          GN  Emissions from Energy use in agriculture            788
# 1          GN  Emissions from Energy use in agriculture            788
# 2          GN  Emissions from Energy use in agriculture            788
# 3          GN  Emissions from Energy use in agriculture            788
# 4          GN  Emissions from Energy use in agriculture            788
#
#       area  element_code                    element  item_code  \
# 0  Tunisia         72184  Energy use in agriculture       6801
# 1  Tunisia         72184  Energy use in agriculture       6801
# 2  Tunisia         72184  Energy use in agriculture       6801
# 3  Tunisia         72184  Energy use in agriculture       6801
# 4  Tunisia         72184  Energy use in agriculture       6801
#
#                  item  year_code  year unit    value flag flag_description
# 0  Petroleum products       1990  1990   TJ   9415.4    E  Estimated value
# 1  Petroleum products       1991  1991   TJ  10927.0    E  Estimated value
# 2  Petroleum products       1992  1992   TJ  12450.4    E  Estimated value
# 3  Petroleum products       1993  1993   TJ  14151.0    E  Estimated value
# 4  Petroleum products       1994  1994   TJ  13958.2    E  Estimated value
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Climate Change-Agrifood systems emissions/Farm gate/Emissions from Energy use in agriculture.csv
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Population and employment/Employment indicators/Employment Indicators-Agriculture and agrifood systems.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 939 entries, 0 to 938
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       939 non-null    object
#  1   domain            939 non-null    object
#  2   area_code_m49     939 non-null    int64
#  3   area              939 non-null    object
#  4   indicator_code    939 non-null    int64
#  5   indicator         939 non-null    object
#  6   sex_code          939 non-null    int64
#  7   sex               939 non-null    object
#  8   year_code         939 non-null    int64
#  9   year              939 non-null    int64
#  10  element_code      939 non-null    int64
#  11  element           939 non-null    object
#  12  source_code       939 non-null    int64
#  13  source            939 non-null    object
#  14  unit              939 non-null    object
#  15  value             939 non-null    float64
#  16  flag              939 non-null    object
#  17  flag_description  939 non-null    object
#  18  note              939 non-null    object
# dtypes: float64(1), int64(7), object(11)
# memory usage: 139.5+ KB
# None
#   domain_code                                             domain  \
# 0         OEA  Employment Indicators: Agriculture and agrifoo...
# 1         OEA  Employment Indicators: Agriculture and agrifoo...
# 2         OEA  Employment Indicators: Agriculture and agrifoo...
# 3         OEA  Employment Indicators: Agriculture and agrifoo...
# 4         OEA  Employment Indicators: Agriculture and agrifoo...
#
#    area_code_m49     area  indicator_code  \
# 0            788  Tunisia           21160
# 1            788  Tunisia           21160
# 2            788  Tunisia           21160
# 3            788  Tunisia           21160
# 4            788  Tunisia           21160
#
#                                     indicator  sex_code    sex  year_code  \
# 0  Total employment in agrifood systems (AFS)         1  Total       2000
# 1  Total employment in agrifood systems (AFS)         1  Total       2001
# 2  Total employment in agrifood systems (AFS)         1  Total       2002
# 3  Total employment in agrifood systems (AFS)         1  Total       2003
# 4  Total employment in agrifood systems (AFS)         1  Total       2004
#
#    year  element_code element  source_code     source     unit   value flag  \
# 0  2000          6199   Value         3044  FAO Model  1000 No  897.34    E
# 1  2001          6199   Value         3044  FAO Model  1000 No  894.89    E
# 2  2002          6199   Value         3044  FAO Model  1000 No  894.69    E
# 3  2003          6199   Value         3044  FAO Model  1000 No  910.15    E
# 4  2004          6199   Value         3044  FAO Model  1000 No  899.15    E
#
#   flag_description                        note
# 0  Estimated value  Modelled using ISIC shares
# 1  Estimated value  Modelled using ISIC shares
# 2  Estimated value  Modelled using ISIC shares
# 3  Estimated value  Modelled using ISIC shares
# 4  Estimated value  Modelled using ISIC shares
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Population and employment/Employment indicators/Employment Indicators-Agriculture and agrifood systems.csv
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Population and employment/Employment indicators/Employment Indicators-Rural.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 959 entries, 0 to 958
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       959 non-null    object
#  1   domain            959 non-null    object
#  2   area_code_m49     959 non-null    int64
#  3   area              959 non-null    object
#  4   indicator_code    959 non-null    int64
#  5   indicator         959 non-null    object
#  6   sex_code          959 non-null    int64
#  7   sex               959 non-null    object
#  8   year_code         959 non-null    int64
#  9   year              959 non-null    int64
#  10  element_code      959 non-null    int64
#  11  element           959 non-null    object
#  12  source_code       959 non-null    int64
#  13  source            959 non-null    object
#  14  unit              959 non-null    object
#  15  value             959 non-null    float64
#  16  flag              959 non-null    object
#  17  flag_description  959 non-null    object
#  18  note              959 non-null    object
# dtypes: float64(1), int64(7), object(11)
# memory usage: 142.5+ KB
# None
#   domain_code                        domain  area_code_m49     area  \
# 0         OER  Employment Indicators: Rural            788  Tunisia
# 1         OER  Employment Indicators: Rural            788  Tunisia
# 2         OER  Employment Indicators: Rural            788  Tunisia
# 3         OER  Employment Indicators: Rural            788  Tunisia
# 4         OER  Employment Indicators: Rural            788  Tunisia
#
#    indicator_code                                    indicator  sex_code  \
# 0           21087  Employment by age, total (15+), rural areas         1
# 1           21087  Employment by age, total (15+), rural areas         1
# 2           21087  Employment by age, total (15+), rural areas         1
# 3           21087  Employment by age, total (15+), rural areas         1
# 4           21087  Employment by age, total (15+), rural areas         1
#
#      sex  year_code  year  element_code element  source_code  \
# 0  Total       2006  2006          6199   Value         3023
# 1  Total       2007  2007          6199   Value         3023
# 2  Total       2008  2008          6199   Value         3023
# 3  Total       2009  2009          6199   Value         3023
# 4  Total       2010  2010          6199   Value         3023
#
#                 source     unit    value flag  \
# 0  Labour force survey  1000 No   980.28    X
# 1  Labour force survey  1000 No   983.51    X
# 2  Labour force survey  1000 No   988.12    X
# 3  Labour force survey  1000 No  1042.24    X
# 4  Labour force survey  1000 No  1082.89    X
#
#                           flag_description  \
# 0  Figure from international organizations
# 1  Figure from international organizations
# 2  Figure from international organizations
# 3  Figure from international organizations
# 4  Figure from international organizations
#
#                                                 note
# 0  Repository: ILO-STATISTICS - Micro data proces...
# 1  Repository: ILO-STATISTICS - Micro data proces...
# 2  Repository: ILO-STATISTICS - Micro data proces...
# 3  Repository: ILO-STATISTICS - Micro data proces...
# 4  Repository: ILO-STATISTICS - Micro data proces...
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Population and employment/Employment indicators/Employment Indicators-Rural.csv
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Discontinued archives and data series/Machinery.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 761 entries, 0 to 760
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       761 non-null    object
#  1   domain            761 non-null    object
#  2   area_code_m49     761 non-null    int64
#  3   area              761 non-null    object
#  4   element_code      761 non-null    int64
#  5   element           761 non-null    object
#  6   item_code         761 non-null    int64
#  7   item              761 non-null    object
#  8   year_code         761 non-null    int64
#  9   year              761 non-null    int64
#  10  unit              761 non-null    object
#  11  value             761 non-null    float64
#  12  flag              761 non-null    object
#  13  flag_description  761 non-null    object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 83.4+ KB
# None
#   domain_code     domain  area_code_m49     area  element_code       element  \
# 0          RM  Machinery            788  Tunisia          5622  Import Value
# 1          RM  Machinery            788  Tunisia          5622  Import Value
# 2          RM  Machinery            788  Tunisia          5922  Export Value
# 3          RM  Machinery            788  Tunisia          5622  Import Value
# 4          RM  Machinery            788  Tunisia          5622  Import Value
#
#    item_code                                item  year_code  year      unit  \
# 0    2455017  Agricultural machinery nes (trade)       1966  1966  1000 USD
# 1    2455017  Agricultural machinery nes (trade)       1967  1967  1000 USD
# 2    2455017  Agricultural machinery nes (trade)       1967  1967  1000 USD
# 3    2455017  Agricultural machinery nes (trade)       1968  1968  1000 USD
# 4    2455017  Agricultural machinery nes (trade)       1969  1969  1000 USD
#
#    value flag flag_description
# 0   37.0    A  Official figure
# 1  121.0    A  Official figure
# 2    1.0    A  Official figure
# 3   77.0    A  Official figure
# 4  164.0    A  Official figure
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Discontinued archives and data series/Machinery.csv
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Trade/Crops and livestock products indicators.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 835 entries, 0 to 834
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       835 non-null    object
#  1   domain            835 non-null    object
#  2   area_code_m49     835 non-null    int64
#  3   area              835 non-null    object
#  4   indicator_code    835 non-null    float64
#  5   indicator         835 non-null    object
#  6   item_code_cpc     835 non-null    object
#  7   item              835 non-null    object
#  8   year_code         835 non-null    int64
#  9   year              835 non-null    int64
#  10  value             835 non-null    float64
#  11  flag              835 non-null    object
#  12  flag_description  835 non-null    object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 84.9+ KB
# None
#   domain_code                                   domain  area_code_m49  \
# 0        TCLI  Crops and livestock products indicators            788
# 1        TCLI  Crops and livestock products indicators            788
# 2        TCLI  Crops and livestock products indicators            788
# 3        TCLI  Crops and livestock products indicators            788
# 4        TCLI  Crops and livestock products indicators            788
#
#       area  indicator_code                             indicator  \
# 0  Tunisia          501.00               Import dependency ratio
# 1  Tunisia          502.00                Self-sufficiency ratio
# 2  Tunisia          507.00     Import market concentration index
# 3  Tunisia          508.00     Export market concentration index
# 4  Tunisia          509.02  Revealed comparative advantage index
#
#   item_code_cpc    item  year_code  year  value flag flag_description
# 0         01341  Apples       2010  2010   0.00    E  Estimated value
# 1         01341  Apples       2010  2010   1.00    E  Estimated value
# 2         01341  Apples       2010  2010   0.19    E  Estimated value
# 3         01341  Apples       2010  2010   0.22    E  Estimated value
# 4         01341  Apples       2010  2010   0.00    E  Estimated value
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Trade/Crops and livestock products indicators.csv
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Trade/Crops and livestock products.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211121 entries, 0 to 211120
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   domain_code       211121 non-null  object
#  1   domain            211121 non-null  object
#  2   area_code_m49     211121 non-null  int64
#  3   area              211121 non-null  object
#  4   element_code      211121 non-null  int64
#  5   element           211121 non-null  object
#  6   item_code_cpc     211121 non-null  object
#  7   item              211121 non-null  object
#  8   year_code         211121 non-null  int64
#  9   year              211121 non-null  int64
#  10  unit              211121 non-null  object
#  11  value             211121 non-null  float64
#  12  flag              211121 non-null  object
#  13  flag_description  211121 non-null  object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 22.6+ MB
# None
#   domain_code                        domain  area_code_m49     area  \
# 0         TCL  Crops and livestock products            788  Tunisia
# 1         TCL  Crops and livestock products            788  Tunisia
# 2         TCL  Crops and livestock products            788  Tunisia
# 3         TCL  Crops and livestock products            788  Tunisia
# 4         TCL  Crops and livestock products            788  Tunisia
#
#    element_code          element item_code_cpc                     item  \
# 0          5610  Import quantity      01929.07  Abaca, manila hemp, raw
# 1          5622     Import value      01929.07  Abaca, manila hemp, raw
# 2          5922     Export value      01929.07  Abaca, manila hemp, raw
# 3          5610  Import quantity      01929.07  Abaca, manila hemp, raw
# 4          5622     Import value      01929.07  Abaca, manila hemp, raw
#
#    year_code  year      unit  value flag flag_description
# 0       1961  1961         t    0.0    A  Official figure
# 1       1961  1961  1000 USD    0.0    A  Official figure
# 2       1961  1961  1000 USD    0.0    A  Official figure
# 3       1962  1962         t    0.0    A  Official figure
# 4       1962  1962  1000 USD    0.0    A  Official figure
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Trade/Crops and livestock products.csv
#
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Land, Inputs and Sustainability/Climate change indicators/Temperature change on land.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2142 entries, 0 to 2141
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       2142 non-null   object
#  1   domain            2142 non-null   object
#  2   area_code_m49     2142 non-null   int64
#  3   area              2142 non-null   object
#  4   element_code      2142 non-null   int64
#  5   element           2142 non-null   object
#  6   months_code       2142 non-null   int64
#  7   months            2142 non-null   object
#  8   year_code         2142 non-null   int64
#  9   year              2142 non-null   int64
#  10  unit              2142 non-null   object
#  11  value             2142 non-null   float64
#  12  flag              2142 non-null   object
#  13  flag_description  2142 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 234.4+ KB
# None
#   domain_code                      domain  area_code_m49     area  \
# 0          ET  Temperature change on land            788  Tunisia
# 1          ET  Temperature change on land            788  Tunisia
# ...
# dtypes: float64(1), int64(5), object(8)
# memory usage: 185.0+ KB
# None
#   domain_code    domain  area_code_m49     area  element_code element  \
# 0          RL  Land Use            788  Tunisia          5110    Area
# 1          RL  Land Use            788  Tunisia          5110    Area
# 2          RL  Land Use            788  Tunisia          5110    Area
# 3          RL  Land Use            788  Tunisia          5110    Area
# 4          RL  Land Use            788  Tunisia          5110    Area
#
#    item_code          item  year_code  year     unit    value flag  \
# 0       6600  Country area       1961  1961  1000 ha  16361.0    A
# 1       6600  Country area       1962  1962  1000 ha  16361.0    A
# 2       6600  Country area       1963  1963  1000 ha  16361.0    A
# 3       6600  Country area       1964  1964  1000 ha  16361.0    A
# 4       6600  Country area       1965  1965  1000 ha  16361.0    A
#
#   flag_description
# 0  Official figure
# 1  Official figure
# 2  Official figure
# 3  Official figure
# 4  Official figure
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Land, Inputs and Sustainability/Land/Land Use.csv
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Land, Inputs and Sustainability/Land/Land Cover.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 778 entries, 0 to 777
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       778 non-null    object
#  1   domain            778 non-null    object
#  2   area_code_m49     778 non-null    int64
#  3   area              778 non-null    object
#  4   element_code      778 non-null    int64
#  5   element           778 non-null    object
#  6   item_code         778 non-null    int64
#  7   item              778 non-null    object
#  8   year_code         778 non-null    int64
#  9   year              778 non-null    int64
#  10  unit              778 non-null    object
#  11  value             778 non-null    float64
#  12  flag              778 non-null    object
#  13  flag_description  778 non-null    object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 85.2+ KB
# None
#   domain_code      domain  area_code_m49     area  element_code  \
# 0          LC  Land Cover            788  Tunisia          5006
# 1          LC  Land Cover            788  Tunisia          5006
# 2          LC  Land Cover            788  Tunisia          5006
# 3          LC  Land Cover            788  Tunisia          5006
# 4          LC  Land Cover            788  Tunisia          5006
#
#           element  item_code  \
# 0  Area from CGLS       6970
# 1  Area from CGLS       6970
# 2  Area from CGLS       6970
# 3  Area from CGLS       6970
# 4  Area from CGLS       6970
#
#                                                 item  year_code  year  \
# 0  Artificial surfaces (including urban and assoc...       2015  2015
# 1  Artificial surfaces (including urban and assoc...       2016  2016
# 2  Artificial surfaces (including urban and assoc...       2017  2017
# 3  Artificial surfaces (including urban and assoc...       2018  2018
# 4  Artificial surfaces (including urban and assoc...       2019  2019
#
#       unit   value flag flag_description
# 0  1000 ha  285.31    E  Estimated value
# 1  1000 ha  285.48    E  Estimated value
# 2  1000 ha  285.62    E  Estimated value
# 3  1000 ha  285.77    E  Estimated value
# 4  1000 ha  286.34    E  Estimated value
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Land, Inputs and Sustainability/Land/Land Cover.csv
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Land, Inputs and Sustainability/Land/Fertilizers by Nutrient.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1171 entries, 0 to 1170
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       1171 non-null   object
#  1   domain            1171 non-null   object
#  2   area_code_m49     1171 non-null   int64
#  3   area              1171 non-null   object
#  4   element_code      1171 non-null   int64
#  5   element           1171 non-null   object
#  6   item_code         1171 non-null   int64
#  7   item              1171 non-null   object
#  8   year_code         1171 non-null   int64
#  9   year              1171 non-null   int64
#  10  unit              1171 non-null   object
#  11  value             1171 non-null   float64
#  12  flag              1171 non-null   object
#  13  flag_description  1171 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 128.2+ KB
# None
#   domain_code                   domain  area_code_m49     area  element_code  \
# 0         RFN  Fertilizers by Nutrient            788  Tunisia          5610
# 1         RFN  Fertilizers by Nutrient            788  Tunisia          5157
# 2         RFN  Fertilizers by Nutrient            788  Tunisia          5159
# 3         RFN  Fertilizers by Nutrient            788  Tunisia          5172
# 4         RFN  Fertilizers by Nutrient            788  Tunisia          5173
#
#                                     element  item_code  \
# 0                           Import quantity       3102
# 1                          Agricultural Use       3102
# 2                  Use per area of cropland       3102
# 3                            Use per capita       3102
# 4  Use per value of agricultural production       3102
#
#                           item  year_code  year    unit    value flag  \
# 0  Nutrient nitrogen N (total)       1961  1961       t  3000.00    X
# 1  Nutrient nitrogen N (total)       1961  1961       t  3000.00    X
# 2  Nutrient nitrogen N (total)       1961  1961   kg/ha     0.71    E
# 3  Nutrient nitrogen N (total)       1961  1961  kg/cap     0.71    E
# 4  Nutrient nitrogen N (total)       1961  1961  g/Int$     2.52    E
#
#                           flag_description
# 0  Figure from international organizations
# 1  Figure from international organizations
# 2                          Estimated value
# 3                          Estimated value
# 4                          Estimated value
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Land, Inputs and Sustainability/Land/Fertilizers by Nutrient.csv
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/World Census of Agriculture/Structural data from agricultural censuses.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       62 non-null     object
#  1   domain            62 non-null     object
#  2   area_code_m49     62 non-null     int64
#  3   area              62 non-null     object
#  4   element_code      62 non-null     int64
#  5   element           62 non-null     object
#  6   item_code         62 non-null     int64
#  7   item              62 non-null     object
#  8   wca_round         62 non-null     int64
#  9   unit              62 non-null     object
#  10  value             62 non-null     float64
#  11  flag              62 non-null     object
#  12  flag_description  62 non-null     object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 6.4+ KB
# None
#   domain_code                                      domain  area_code_m49  \
# 0        WCAD  Structural data from agricultural censuses            788
# 1        WCAD  Structural data from agricultural censuses            788
# 2        WCAD  Structural data from agricultural censuses            788
# 3        WCAD  Structural data from agricultural censuses            788
# 4        WCAD  Structural data from agricultural censuses            788
#
#       area  element_code       element  item_code      item  wca_round unit  \
# 0  Tunisia         50260          Area      27002  Holdings       1960   ha
# 1  Tunisia          5017  Average area      27002  Holdings       1960   ha
# 2  Tunisia         60850        Number      27002  Holdings       1960   No
# 3  Tunisia         50260          Area      27002  Holdings       1990   ha
# 4  Tunisia          5017  Average area      27002  Holdings       1990   ha
#
#         value flag flag_description
# 0  5022000.00    A  Official figure
# 1       15.41    A  Official figure
# 2   325800.00    A  Official figure
# 3  5455300.00    A  Official figure
# 4       11.58    A  Official figure
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/World Census of Agriculture/Structural data from agricultural censuses.csv
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Investment/Credit to Agriculture.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain_code       330 non-null    object
#  1   domain            330 non-null    object
#  2   area_code_m49     330 non-null    int64
#  3   area              330 non-null    object
#  4   element_code      330 non-null    int64
#  5   element           330 non-null    object
#  6   item_code         330 non-null    int64
#  7   item              330 non-null    object
#  8   year_code         330 non-null    int64
#  9   year              330 non-null    int64
#  10  unit              330 non-null    object
#  11  value             330 non-null    float64
#  12  flag              330 non-null    object
#  13  flag_description  330 non-null    object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 36.2+ KB
# None
#   domain_code                 domain  area_code_m49     area  element_code  \
# 0          IC  Credit to Agriculture            788  Tunisia          6224
# 1          IC  Credit to Agriculture            788  Tunisia          6224
# 2          IC  Credit to Agriculture            788  Tunisia          6224
# 3          IC  Credit to Agriculture            788  Tunisia          6224
# 4          IC  Credit to Agriculture            788  Tunisia          6224
#
#                          element  item_code          item  year_code  year  \
# 0  Value Standard Local Currency      23018  Total Credit       1991  1991
# 1  Value Standard Local Currency      23018  Total Credit       1992  1992
# 2  Value Standard Local Currency      23018  Total Credit       1993  1993
# 3  Value Standard Local Currency      23018  Total Credit       1994  1994
# 4  Value Standard Local Currency      23018  Total Credit       1995  1995
#
#           unit      value flag flag_description
# 0  million SLC   7170.227    A  Official figure
# 1  million SLC   8206.844    A  Official figure
# 2  million SLC   9279.671    A  Official figure
# 3  million SLC  10111.865    A  Official figure
# 4  million SLC  11017.368    A  Official figure
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Investment/Credit to Agriculture.csv
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
# 🔍 Processing: /content/drive/My Drive/FarmWise/Cleaned_Data/FAO/Investment/Development Flows to Agriculture.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71616 entries, 0 to 71615
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   domain_code                 71616 non-null  object
#  1   domain                      71616 non-null  object
#  2   recipient_country_code_m49  71616 non-null  int64
#  3   recipient_country           71616 non-null  object
#  4   donor_code_m49              71616 non-null  object
#  5   donor                       71616 non-null  object
#  6   element_code                71616 non-null  int64
#  7   element                     71616 non-null  object
#  8   item_code                   71616 non-null  int64
#  9   item                        71616 non-null  object
#  10  purpose_code                71616 non-null  int64
#  11  purpose                     71616 non-null  object
#  12  year_code                   71616 non-null  int64
#  13  year                        71616 non-null  int64
#  14  unit                        71616 non-null  object
#  15  value                       71616 non-null  float64
#  16  flag                        71616 non-null  object
#  17  flag_description            71616 non-null  object
# dtypes: float64(1), int64(6), object(11)
# memory usage: 9.8+ MB
# None
#   domain_code                            domain  recipient_country_code_m49  \
# 0          EA  Development Flows to Agriculture                         788
# 1          EA  Development Flows to Agriculture                         788
# 2          EA  Development Flows to Agriculture                         788
# 3          EA  Development Flows to Agriculture                         788
# 4          EA  Development Flows to Agriculture                         788
#
#   recipient_country donor_code_m49       donor  element_code    element  \
# 0           Tunisia           F702  All Donors          6110  Value US$
# 1           Tunisia           F702  All Donors          6110  Value US$
# 2           Tunisia           F702  All Donors          6110  Value US$
# 3           Tunisia           F702  All Donors          6110  Value US$
# 4           Tunisia           F702  All Donors          6110  Value US$
#
#    item_code        item  purpose_code           purpose  year_code  year  \
# 0      22040  Commitment         10000  All CRS purposes       1973  1973
# 1      22040  Commitment         10000  All CRS purposes       1974  1974
# 2      22040  Commitment         10000  All CRS purposes       1975  1975
# 3      22040  Commitment         10000  All CRS purposes       1976  1976
# 4      22040  Commitment         10000  All CRS purposes       1977  1977
#
#           unit       value flag                         flag_description
# 0  million USD  173.384000    X  Figure from international organizations
# 1  million USD  157.637721    X  Figure from international organizations
# 2  million USD  111.650563    X  Figure from international organizations
# 3  million USD  146.527241    X  Figure from international organizations
# 4  million USD  137.446981    X  Figure from international organizations
# <ipython-input-1-7e28368b82df>:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')  # Forward fill missing values
#  ✅ Processed dataset saved: /content/drive/My Drive/FarmWise/Processed_Data/FAO/Investment/Development Flows to Agriculture.csv
#
#  ✅ All datasets (including subfolders) have been processed and saved!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.model_selection import train_test_split

# Step 1: Import the merged data
merged_data = pd.read_csv('merged_food_market_data.csv')

# Check the first few rows to understand the structure of the data
print(merged_data.head())

# Step 2: Handle missing values (if any)
# You can drop rows with missing values or fill them with a specific value
merged_data.dropna(inplace=True)  # Remove missing values, or you can use fillna() for filling

# Step 3: If necessary, create a 'Date' column if not already present
# Assuming 'Year' and 'Month' columns exist, we create a 'Date' column
if 'Date' not in merged_data.columns:
    merged_data['Date'] = pd.to_datetime(merged_data['Month'] + ' ' + merged_data['Year'].astype(str))

# Step 4: Select the column to predict (you can replace with your target column name)
column_to_predict = 'Grocery stores sales million nominal U.S. dollars with taxes and tips'  # Replace with your column name

# Ensure that the column exists
if column_to_predict not in merged_data.columns:
    raise KeyError(f"The column '{column_to_predict}' is not in the dataset!")

# Select only the target column for prediction
data = merged_data[[column_to_predict]]

# Step 5: Normalize the data using MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Step 6: Create the dataset for LSTM
def create_dataset(data, time_step=12):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:(i + time_step), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

# Prepare data for training and testing
time_step = 12  # Number of time steps (months in this case)
X, y = create_dataset(scaled_data, time_step)

# Reshape X to be 3D as required by LSTM [samples, time_steps, features]
X = X.reshape(X.shape[0], X.shape[1], 1)

# Step 7: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Step 8: Build the LSTM model
model = Sequential()
model.add(LSTM(units=100, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(units=100, return_sequences=False))
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Step 9: Train the LSTM model
history = model.fit(X_train, y_train, epochs=100, batch_size=2, validation_data=(X_test, y_test), verbose=1)

# Step 10: Make predictions using the model
predictions = model.predict(X_test)

# Step 11: Inverse transform the predictions and actual values to get them back to the original scale
predictions = scaler.inverse_transform(predictions)
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Step 12: Visualize the results
plt.figure(figsize=(10, 6))
plt.plot(y_test_actual, color='blue', label='Actual Sales')
plt.plot(predictions, color='red', label='Predicted Sales')
plt.title('Sales Forecasting using LSTM')
plt.xlabel('Time')
plt.ylabel('Sales')
plt.legend()
plt.show()
# Out:
#    Year      Month  \
# 0  2024   November
# 1  2024    October
# 2  2024  September
# 3  2024     August
# 4  2024       July
#
#    Food at home sales million nominal U.S. dollars with taxes and tips  \
# 0                                           95656.09
# 1                                           93264.84
# 2                                           88347.26
# 3                                           93574.33
# 4                                           92725.62
#
#    Food away from home sales million nominal U.S. dollars with taxes and tips  \
# 0                                          114435.81
# 1                                          117611.72
# 2                                          113183.13
# 3                                          120947.75
# 4                                          118376.29
#
#    Total food sales million nominal U.S. dollars with taxes and tips  \
# 0                                          210091.91
# 1                                          210876.56
# 2                                          201530.38
# 3                                          214522.08
# 4                                          211101.91
#
#    Food at home sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                           36217.51
# 1                                           35286.00
# 2                                           33472.50
# 3                                           35610.85
# 4                                           35260.13
#
#    Food away from home sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                           37323.76
# 1                                           38467.11
# 2                                           37106.51
# 3                                           39786.59
# 4                                           39042.41
#
#    Total food sales million constant 1988 U.S. dollars with taxes and tips_x  \
# 0                                           73541.27
# 1                                           73753.11
# 2                                           70579.02
# 3                                           75397.44
# 4                                           74302.53
#
#    Grocery stores sales million nominal U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Warehouse clubs and supercenters sales million nominal U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Grocery stores sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Warehouse clubs and supercenters sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Other food at home sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Total food at home sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Full-service restaurants sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Limited-service restaurants sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Other food away from home sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Total food away from home sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Total food sales million constant 1988 U.S. dollars with taxes and tips_y  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#          Date
# 0  2024-11-01
# 1  2024-10-01
# 2  2024-09-01
# 3  2024-08-01
# 4  2024-07-01
#
# [5 rows x 27 columns]
# Epoch 1/100
# 125/125 [==============================] - 5s 13ms/step - loss: 0.0114 - val_loss: 0.0018
# Epoch 2/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0061 - val_loss: 0.0019
# Epoch 3/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 4/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0029 - val_loss: 0.0039
# Epoch 5/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0046 - val_loss: 0.0013
# Epoch 6/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 7/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 8/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0035 - val_loss: 0.0017
# Epoch 9/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 10/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 11/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 12/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 13/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0032 - val_loss: 0.0016
# Epoch 14/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 15/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0033 - val_loss: 0.0014
# Epoch 16/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 17/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0027 - val_loss: 0.0015
# Epoch 18/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0030 - val_loss: 0.0039
# Epoch 19/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 20/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0032 - val_loss: 0.0013
# Epoch 21/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 22/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 23/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 24/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 25/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 26/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 27/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 28/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 29/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 30/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 31/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0025 - val_loss: 0.0018
# Epoch 32/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 33/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 34/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 35/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 36/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0027 - val_loss: 0.0018
# Epoch 37/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 0.0016
# Epoch 38/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0026 - val_loss: 0.0044
# Epoch 39/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 40/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 41/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 42/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 43/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 44/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 45/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 46/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 47/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0034 - val_loss: 0.0023
# Epoch 48/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 49/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 50/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 51/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 52/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 53/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 54/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 55/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 56/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 57/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 58/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 59/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 60/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 61/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 62/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 63/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 64/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0031 - val_loss: 0.0013
# Epoch 65/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 66/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 67/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 68/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 0.0012
# Epoch 69/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 70/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0023 - val_loss: 0.0010
# Epoch 71/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0021 - val_loss: 9.8849e-04
# Epoch 72/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 0.0011
# Epoch 73/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 74/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 75/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 9.5401e-04
# Epoch 76/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0019 - val_loss: 9.0989e-04
# Epoch 77/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 0.0016
# Epoch 78/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0022 - val_loss: 0.0010
# Epoch 79/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 80/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 81/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0019 - val_loss: 7.8096e-04
# Epoch 82/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 83/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 84/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 85/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0021 - val_loss: 8.5642e-04
# Epoch 86/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0020 - val_loss: 9.4313e-04
# Epoch 87/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 88/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 89/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0020 - val_loss: 8.6069e-04
# Epoch 90/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 91/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0017 - val_loss: 9.6904e-04
# Epoch 92/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0017 - val_loss: 7.1606e-04
# Epoch 93/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0018 - val_loss: 7.7534e-04
# Epoch 94/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 95/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 96/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 97/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0020 - val_loss: 7.9093e-04
# Epoch 98/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 99/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 100/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0018 - val_loss: 8.2391e-04
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7e4732eb2e50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 4ms/step

# %%
# Out:
# Requirement already satisfied: tensorflow in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (2.13.1)
# Requirement already satisfied: absl-py>=1.0.0 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (2.13.1)
# Requirement already satisfied: libclang>=13.0.0 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: setuptools in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (75.3.0)
# Requirement already satisfied: six>=1.12.0 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (3.0.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow) (8.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow) (2.1.5)
# Requirement already satisfied: zipp>=3.20 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow) (3.20.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
df_merged.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_merged.info()
#
# NameError: name 'df_merged' is not defined

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 324 entries, 11 to 334
# Data columns (total 27 columns):
#  #   Column                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                         --------------  -----
#  0   Year                                                                                           324 non-null    int64
#  1   Month                                                                                          324 non-null    object
#  2   Food at home sales million nominal U.S. dollars with taxes and tips                            324 non-null    float64
#  3   Food away from home sales million nominal U.S. dollars with taxes and tips                     324 non-null    float64
#  4   Total food sales million nominal U.S. dollars with taxes and tips                              324 non-null    float64
#  5   Food at home sales million constant 1988 U.S. dollars with taxes and tips                      324 non-null    float64
#  6   Food away from home sales million constant 1988 U.S. dollars with taxes and tips               324 non-null    float64
#  7   Total food sales million constant 1988 U.S. dollars with taxes and tips_x                      324 non-null    float64
#  8   Grocery stores sales million nominal U.S. dollars with taxes and tips                          324 non-null    float64
#  9   Warehouse clubs and supercenters sales million nominal U.S. dollars with taxes and tips        324 non-null    float64
#  10  Other food at home sales million nominal U.S. dollars with taxes and tips                      324 non-null    float64
#  11  Total food at home sales million nominal U.S. dollars with taxes and tips                      324 non-null    float64
#  12  Full-service restaurants sales million nominal U.S. dollars with taxes and tips                324 non-null    float64
#  13  Limited-service restaurants sales million nominal U.S. dollars with taxes and tips             324 non-null    float64
#  14  Other food away from home sales million nominal U.S. dollars with taxes and tips               324 non-null    float64
#  15  Total food away from home sales million nominal U.S. dollars with taxes and tips               324 non-null    float64
#  16  Total nominal U.S. dollars food sales with taxes and tips                                      324 non-null    float64
#  17  Grocery stores sales million constant 1988 U.S. dollars with taxes and tips                    324 non-null    float64
#  18  Warehouse clubs and supercenters sales million constant 1988 U.S. dollars with taxes and tips  324 non-null    float64
#  19  Other food at home sales million constant 1988 U.S. dollars with taxes and tips                324 non-null    float64
#  20  Total food at home sales million constant 1988 U.S. dollars with taxes and tips                324 non-null    float64
#  21  Full-service restaurants sales million constant 1988 U.S. dollars with taxes and tips          324 non-null    float64
#  22  Limited-service restaurants sales million constant 1988 U.S. dollars with taxes and tips       324 non-null    float64
#  23  Other food away from home sales million constant 1988 U.S. dollars with taxes and tips         324 non-null    float64
#  24  Total food away from home sales million constant 1988 U.S. dollars with taxes and tips         324 non-null    float64
#  25  Total food sales million constant 1988 U.S. dollars with taxes and tips_y                      324 non-null    float64
#  26  Date                                                                                           324 non-null    object
# dtypes: float64(24), int64(1), object(2)
# memory usage: 70.9+ KB

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Step 13: Calculate metrics

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test_actual, predictions)

# Mean Squared Error (MSE)
mse = mean_squared_error(y_test_actual, predictions)

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# R-squared (R²)
r2 = r2_score(y_test_actual, predictions)

# Print the metrics
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'R-squared (R²): {r2}')
# Out:
# Mean Absolute Error (MAE): 702.7212549603171
# Mean Squared Error (MSE): 818201.2641387522
# Root Mean Squared Error (RMSE): 904.544782826562
# R-squared (R²): 0.5669351426425613

# %%
pip install keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from keras-tuner) (2.13.1)
# Requirement already satisfied: packaging in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from keras-tuner) (24.2)
# Requirement already satisfied: requests in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from keras-tuner) (2.32.3)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from requests->keras-tuner) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from requests->keras-tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from requests->keras-tuner) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/iyed/FarmWise/tf-env/venv/lib/python3.8/site-packages (from requests->keras-tuner) (2025.1.31)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Best hyperparameters
best_hyperparameters = {
    'units_1': 50,
    'dropout_1': 0.4,
    'units_2': 150,
    'dropout_2': 0.2,
    'learning_rate': 0.00021686067491772116,
}

# Rebuild the model with best hyperparameters
model = Sequential()
model.add(LSTM(units=best_hyperparameters['units_1'], return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(best_hyperparameters['dropout_1']))
model.add(LSTM(units=best_hyperparameters['units_2']))
model.add(Dropout(best_hyperparameters['dropout_2']))
model.add(Dense(1))

# Compile the model with the specified learning rate
optimizer = Adam(learning_rate=best_hyperparameters['learning_rate'])
model.compile(optimizer=optimizer, loss='mean_squared_error')

# Train the model with your data (X_train, y_train)
history = model.fit(X_train, y_train, epochs=100, batch_size=2, validation_data=(X_test, y_test), verbose=1)

# Step 2: Evaluate the model on test data
predictions = model.predict(X_test)

# Inverse transform predictions and actual values
predictions_rescaled = scaler.inverse_transform(predictions)
y_test_actual_rescaled = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate performance metrics
mae = mean_absolute_error(y_test_actual_rescaled, predictions_rescaled)
mse = mean_squared_error(y_test_actual_rescaled, predictions_rescaled)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_actual_rescaled, predictions_rescaled)

# Display the metrics
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R²): {r2}")
# Out:
# Epoch 1/100
# 125/125 [==============================] - 4s 12ms/step - loss: 0.0245 - val_loss: 0.0054
# Epoch 2/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0037 - val_loss: 0.0017
# Epoch 3/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0038 - val_loss: 0.0022
# Epoch 4/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 5/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0039 - val_loss: 0.0015
# Epoch 6/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0040 - val_loss: 0.0014
# Epoch 7/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 8/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 9/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 10/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0035 - val_loss: 0.0013
# Epoch 11/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0034 - val_loss: 0.0013
# Epoch 12/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0032 - val_loss: 0.0022
# Epoch 13/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0031 - val_loss: 0.0013
# Epoch 14/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0029 - val_loss: 0.0018
# Epoch 15/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0034 - val_loss: 0.0013
# Epoch 16/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 17/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0035 - val_loss: 0.0012
# Epoch 18/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 19/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 20/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0031 - val_loss: 0.0013
# Epoch 21/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 22/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 23/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0032 - val_loss: 0.0013
# Epoch 24/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 25/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0034 - val_loss: 0.0013
# Epoch 26/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0040 - val_loss: 0.0025
# Epoch 27/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0034 - val_loss: 0.0016
# Epoch 28/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0032 - val_loss: 0.0025
# Epoch 29/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0035 - val_loss: 0.0013
# Epoch 30/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 31/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0033 - val_loss: 0.0016
# Epoch 32/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 33/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 34/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0032 - val_loss: 0.0015
# Epoch 35/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 36/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 37/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 38/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 39/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0038 - val_loss: 0.0013
# Epoch 40/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0033 - val_loss: 0.0020
# Epoch 41/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 42/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 43/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0031 - val_loss: 0.0013
# Epoch 44/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 45/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 46/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 47/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0035 - val_loss: 0.0015
# Epoch 48/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 49/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0031 - val_loss: 0.0013
# Epoch 50/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 51/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 52/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 53/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 54/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 55/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 56/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 57/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0031 - val_loss: 0.0013
# Epoch 58/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 59/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 60/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 61/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0034 - val_loss: 0.0013
# Epoch 62/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 63/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 64/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 65/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 66/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 67/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 68/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 69/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0031 - val_loss: 0.0014
# Epoch 70/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 71/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 72/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 73/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 74/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 75/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 76/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 77/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 78/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 79/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0026 - val_loss: 0.0015
# Epoch 80/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 81/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0031 - val_loss: 0.0013
# Epoch 82/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 83/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 84/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 85/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0029 - val_loss: 0.0021
# Epoch 86/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 87/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 88/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 89/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0033 - val_loss: 0.0014
# Epoch 90/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 91/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0028 - val_loss: 0.0018
# Epoch 92/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 93/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 94/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 95/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 96/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 97/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0027 - val_loss: 0.0015
# Epoch 98/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 99/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 100/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0026 - val_loss: 0.0013
# 2/2 [==============================] - 1s 4ms/step
# Mean Absolute Error (MAE): 830.8966703869048
# Mean Squared Error (MSE): 1261980.364153132
# Root Mean Squared Error (RMSE): 1123.3789939967419
# R-squared (R²): 0.33204778537572044

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential  # Add this import
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
import keras_tuner as kt
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Step 1: Import the merged data
merged_data = pd.read_csv('merged_food_market_data.csv')

# Check the first few rows to understand the structure of the data
print(merged_data.head())

# Step 2: Handle missing values (if any)
# You can drop rows with missing values or fill them with a specific value
merged_data.dropna(inplace=True)  # Remove missing values, or you can use fillna() for filling

# Step 3: If necessary, create a 'Date' column if not already present
# Assuming 'Year' and 'Month' columns exist, we create a 'Date' column
if 'Date' not in merged_data.columns:
    merged_data['Date'] = pd.to_datetime(merged_data['Month'] + ' ' + merged_data['Year'].astype(str))

# Step 4: Select the column to predict (you can replace with your target column name)
column_to_predict = 'Grocery stores sales million nominal U.S. dollars with taxes and tips'  # Replace with your column name

# Ensure that the column exists
if column_to_predict not in merged_data.columns:
    raise KeyError(f"The column '{column_to_predict}' is not in the dataset!")

# Select only the target column for prediction
data = merged_data[[column_to_predict]]

# Step 5: Normalize the data using MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Step 6: Create the dataset for LSTM
def create_dataset(data, time_step=12):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:(i + time_step), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

# Prepare data for training and testing
time_step = 12  # Number of time steps (months in this case)
X, y = create_dataset(scaled_data, time_step)

# Reshape X to be 3D as required by LSTM [samples, time_steps, features]
X = X.reshape(X.shape[0], X.shape[1], 1)

# Step 7: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Step 8: Define a model-building function that includes the hyperparameters
def build_model(hp):
    model = Sequential()
    
    # Add the first LSTM layer with variable units
    model.add(LSTM(units=hp.Int('units_1', min_value=50, max_value=150, step=50), 
                   return_sequences=True, input_shape=(X_train.shape[1], 1)))
    
    # Add a Dropout layer for regularization
    model.add(Dropout(rate=hp.Float('dropout_1', min_value=0.4, max_value=0.4, step=0.0)))
    
    # Add the second LSTM layer with variable units
    model.add(LSTM(units=hp.Int('units_2', min_value=50, max_value=150, step=50), 
                   return_sequences=False))
    
    # Add a Dropout layer for regularization
    model.add(Dropout(rate=hp.Float('dropout_2', min_value=0.2, max_value=0.5, step=0.1)))
    
    # Add the output layer
    model.add(Dense(units=1))
    
    # Compile the model with a variable learning rate
    model.compile(optimizer=Adam(learning_rate=hp.Float('learning_rate', min_value=1e-5, max_value=1e-2, sampling='LOG')), 
                  loss='mean_squared_error')
    
    return model

# Step 9: Initialize the tuner
tuner = kt.Hyperband(build_model,
                     objective='val_loss',  # We want to minimize validation loss
                     max_epochs=10**4,         # The maximum number of epochs to train the model
                     factor=3,               # Factor used to reduce the search space
                     directory='my_dir',     # Directory to store tuner results
                     project_name='hyperparameter_tuning')

# Step 10: Perform the hyperparameter search
tuner.search(X_train, y_train, epochs=10**4, batch_size=2, validation_data=(X_test, y_test), verbose=1)

# Step 11: Get the best model and hyperparameters
best_model = tuner.get_best_models(num_models=1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"Best Hyperparameters: {best_hyperparameters.values}")

# Step 12: Evaluate the best model on the test data
test_loss = best_model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")

# Step 13: Make predictions with the best model
predictions = best_model.predict(X_test)

# Step 14: Inverse transform the predictions and actual values to get them back to the original scale
predictions = scaler.inverse_transform(predictions)
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Step 15: Visualize the results
plt.figure(figsize=(10, 6))
plt.plot(y_test_actual, color='blue', label='Actual Sales')
plt.plot(predictions, color='red', label='Predicted Sales')
plt.title('Sales Forecasting using Optimized LSTM')
plt.xlabel('Time')
plt.ylabel('Sales')
plt.legend()
plt.show()

# Step 16: Calculate evaluation metrics
mae = mean_absolute_error(y_test_actual, predictions)
mse = mean_squared_error(y_test_actual, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_actual, predictions)

print(f"Optimized Mean Absolute Error (MAE): {mae}")
print(f"Optimized Mean Squared Error (MSE): {mse}")
print(f"Optimized Root Mean Squared Error (RMSE): {rmse}")
print(f"Optimized R-squared (R²): {r2}")
# Out:
# Trial 230 Complete [00h 00m 29s]
# val_loss: 0.0012774759670719504
#
# Best val_loss So Far: 0.001236744923517108
# Total elapsed time: 00h 43m 43s
#
# Search: Running Trial #231
#
# Value             |Best Value So Far |Hyperparameter
# 100               |50                |units_1
# 0.3               |0.4               |dropout_1
# 100               |150               |units_2
# 0.2               |0.2               |dropout_2
# 0.00018685        |0.00021686        |learning_rate
# 34                |100               |tuner/epochs
# 12                |34                |tuner/initial_epoch
# 2                 |3                 |tuner/bracket
# 1                 |3                 |tuner/round
# 0212              |0203              |tuner/trial_id
#
# Epoch 13/34
# 125/125 [==============================] - 4s 12ms/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 14/34
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 15/34
# 125/125 [==============================] - 1s 6ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 16/34
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 17/34
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 18/34
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 19/34
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0037 - val_loss: 0.0016
# Epoch 20/34
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0037 - val_loss: 0.0019
# Epoch 21/34
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 22/34
#  72/125 [================>.............] - ETA: 0s - loss: 0.0027
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 95
#      87 tuner = kt.Hyperband(build_model,
#      88                      objective='val_loss',  # We want to minimize validation loss
#      89                      max_epochs=10**4,         # The maximum number of epochs to train the model
#      90                      factor=3,               # Factor used to reduce the search space
#      91                      directory='my_dir',     # Directory to store tuner results
#      92                      project_name='hyperparameter_tuning')
#      94 # Step 10: Perform the hyperparameter search
# ---> 95 tuner.search(X_train, y_train, epochs=10**4, batch_size=2, validation_data=(X_test, y_test), verbose=1)
#      97 # Step 11: Get the best model and hyperparameters
#      98 best_model = tuner.get_best_models(num_models=1)[0]
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/base_tuner.py:234, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     231         continue
#     233     self.on_trial_begin(trial)
# --> 234     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235     self.on_trial_end(trial)
#     236 self.on_search_end()
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/base_tuner.py:274, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273     try:
# --> 274         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275         trial.status = trial_module.TrialStatus.COMPLETED
#     276         return
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/base_tuner.py:239, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     238 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241         self.oracle.objective.name
#     242     ):
#     243         # The oracle is updated by calling `self.oracle.update_trial()` in
#     244         # `Tuner.run_trial()`. For backward compatibility, we support this
#     245         # use case. No further action needed in this case.
#     246         warnings.warn(
#     247             "The use case of calling "
#     248             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     254             stacklevel=2,
#     255         )
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/tuners/hyperband.py:427, in Hyperband.run_trial(self, trial, *fit_args, **fit_kwargs)
#     425     fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     426     fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 427 return super().run_trial(trial, *fit_args, **fit_kwargs)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/tuner.py:233, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     231 hp = trial.hyperparameters
#     232 model = self._try_build(hp)
# --> 233 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     235 # Save the build config for model loading later.
#     236 if backend.config.multi_backend():
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/hypermodel.py:149, in HyperModel.fit(self, hp, model, *args, **kwargs)
#     125 def fit(self, hp, model, *args, **kwargs):
#     126     """Train the model.
#     127
#     128     Args:
#    (...)
#     147         If return a float, it should be the `objective` value.
#     148     """
# --> 149     return model.fit(*args, **kwargs)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
import keras_tuner as kt
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Step 1: Import the merged data
merged_data = pd.read_csv('merged_food_market_data.csv')

# Check the first few rows to understand the structure of the data
print(merged_data.head())

# Step 2: Handle missing values (if any)
merged_data.dropna(inplace=True)  # Remove missing values, or you can use fillna() for filling

# Step 3: If necessary, create a 'Date' column if not already present
if 'Date' not in merged_data.columns:
    merged_data['Date'] = pd.to_datetime(merged_data['Month'] + ' ' + merged_data['Year'].astype(str))

# Step 4: Select the column to predict
column_to_predict = 'Grocery stores sales million nominal U.S. dollars with taxes and tips'

if column_to_predict not in merged_data.columns:
    raise KeyError(f"The column '{column_to_predict}' is not in the dataset!")

data = merged_data[[column_to_predict]]

# Step 5: Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Step 6: Create the dataset for LSTM
def create_dataset(data, time_step=12):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:(i + time_step), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

# Prepare data for training and testing
time_step = 12  # Number of time steps (months in this case)
X, y = create_dataset(scaled_data, time_step)
X = X.reshape(X.shape[0], X.shape[1], 1)

# Step 7: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Step 8: Define a model-building function
def build_model(hp):
    model = Sequential()
    
    model.add(LSTM(units=hp.Int('units_1', min_value=50, max_value=150, step=50), 
                   return_sequences=True, input_shape=(X_train.shape[1], 1)))
    
    model.add(Dropout(rate=hp.Float('dropout_1', min_value=0.3, max_value=0.6, step=0.1)))
    
    model.add(LSTM(units=hp.Int('units_2', min_value=50, max_value=150, step=50), 
                   return_sequences=False))
    
    model.add(Dropout(rate=hp.Float('dropout_2', min_value=0.2, max_value=0.5, step=0.1)))
    
    model.add(Dense(units=1))
    
    model.compile(optimizer=Adam(learning_rate=hp.Float('learning_rate', min_value=1e-5, max_value=1e-2, sampling='LOG')), 
                  loss='mean_squared_error')
    
    return model

# Step 9: Initialize the tuner with early stopping and dynamic training duration
tuner = kt.Hyperband(build_model,
                     objective='val_loss',
                     max_epochs=100,  # Limit number of epochs for faster tuning
                     factor=3,
                     directory='my_dir',
                     project_name='hyperparameter_tuning',
                     overwrite=True)

# Step 10: Perform the hyperparameter search
tuner.search(X_train, y_train, epochs=500, batch_size=2, validation_data=(X_test, y_test), verbose=1)

# Step 11: Get the best model and hyperparameters
best_model = tuner.get_best_models(num_models=1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"Best Hyperparameters: {best_hyperparameters.values}")

# Step 12: Evaluate the best model on the test data
test_loss = best_model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")

# Step 13: Make predictions with the best model
predictions = best_model.predict(X_test)

# Step 14: Inverse transform the predictions and actual values
predictions = scaler.inverse_transform(predictions)
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Step 15: Visualize the results
plt.figure(figsize=(10, 6))
plt.plot(y_test_actual, color='blue', label='Actual Sales')
plt.plot(predictions, color='red', label='Predicted Sales')
plt.title('Sales Forecasting using Optimized LSTM')
plt.xlabel('Time')
plt.ylabel('Sales')
plt.legend()
plt.show()

# Step 16: Calculate evaluation metrics
mae = mean_absolute_error(y_test_actual, predictions)
mse = mean_squared_error(y_test_actual, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_actual, predictions)

print(f"Optimized Mean Absolute Error (MAE): {mae}")
print(f"Optimized Mean Squared Error (MSE): {mse}")
print(f"Optimized Root Mean Squared Error (RMSE): {rmse}")
print(f"Optimized R-squared (R²): {r2}")
# Out:
# Trial 68 Complete [00h 00m 06s]
# val_loss: 0.0032345287036150694
#
# Best val_loss So Far: 0.0012909702491015196
# Total elapsed time: 00h 06m 47s
#
# Search: Running Trial #69
#
# Value             |Best Value So Far |Hyperparameter
# 50                |50                |units_1
# 0.4               |0.3               |dropout_1
# 50                |75                |units_2
# 0.3               |0.3               |dropout_2
# 0.0032148         |0.00075383        |learning_rate
# 2                 |2                 |tuner/epochs
# 0                 |0                 |tuner/initial_epoch
# 4                 |4                 |tuner/bracket
# 0                 |0                 |tuner/round
#
# Epoch 1/2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 84
#      75 tuner = kt.Hyperband(build_model,
#      76                      objective='val_loss',
#      77                      max_epochs=100,  # Limit number of epochs for faster tuning
#    (...)
#      80                      project_name='hyperparameter_tuning',
#      81                      overwrite=True)
#      83 # Step 10: Perform the hyperparameter search
# ---> 84 tuner.search(X_train, y_train, epochs=50, batch_size=2, validation_data=(X_test, y_test), verbose=1)
#      86 # Step 11: Get the best model and hyperparameters
#      87 best_model = tuner.get_best_models(num_models=1)[0]
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/base_tuner.py:234, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     231         continue
#     233     self.on_trial_begin(trial)
# --> 234     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235     self.on_trial_end(trial)
#     236 self.on_search_end()
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/base_tuner.py:274, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273     try:
# --> 274         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275         trial.status = trial_module.TrialStatus.COMPLETED
#     276         return
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/base_tuner.py:239, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     238 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241         self.oracle.objective.name
#     242     ):
#     243         # The oracle is updated by calling `self.oracle.update_trial()` in
#     244         # `Tuner.run_trial()`. For backward compatibility, we support this
#     245         # use case. No further action needed in this case.
#     246         warnings.warn(
#     247             "The use case of calling "
#     248             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     254             stacklevel=2,
#     255         )
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/tuners/hyperband.py:427, in Hyperband.run_trial(self, trial, *fit_args, **fit_kwargs)
#     425     fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     426     fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 427 return super().run_trial(trial, *fit_args, **fit_kwargs)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/tuner.py:233, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     231 hp = trial.hyperparameters
#     232 model = self._try_build(hp)
# --> 233 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     235 # Save the build config for model loading later.
#     236 if backend.config.multi_backend():
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/hypermodel.py:149, in HyperModel.fit(self, hp, model, *args, **kwargs)
#     125 def fit(self, hp, model, *args, **kwargs):
#     126     """Train the model.
#     127
#     128     Args:
#    (...)
#     147         If return a float, it should be the `objective` value.
#     148     """
# --> 149     return model.fit(*args, **kwargs)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:890, in Function._call(self, *args, **kwds)
#     886     pass  # Fall through to cond-based initialization.
#     887   else:
#     888     # Lifting succeeded, so variables are initialized and we can run the
#     889     # no_variable_creation function.
# --> 890     return self._no_variable_creation_fn(*args, **kwds)
#     891 else:
#     892   _, _, filtered_flat_args = (
#     893       self._variable_creation_fn._function_spec  # pylint: disable=protected-access
#     894       .canonicalize_function_inputs(
#     895           args, kwds))
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
import keras_tuner as kt
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Step 1: Import the merged data
merged_data = pd.read_csv('merged_food_market_data.csv')

# Check the first few rows to understand the structure of the data
print(merged_data.head())

# Step 2: Handle missing values (if any)
merged_data.dropna(inplace=True)  # Remove missing values, or you can use fillna() for filling

# Step 3: If necessary, create a 'Date' column if not already present
if 'Date' not in merged_data.columns:
    merged_data['Date'] = pd.to_datetime(merged_data['Month'] + ' ' + merged_data['Year'].astype(str))

# Step 4: Select the column to predict
column_to_predict = 'Grocery stores sales million nominal U.S. dollars with taxes and tips'

if column_to_predict not in merged_data.columns:
    raise KeyError(f"The column '{column_to_predict}' is not in the dataset!")

data = merged_data[[column_to_predict]]

# Step 5: Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Step 6: Create the dataset for LSTM
def create_dataset(data, time_step=12):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:(i + time_step), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

# Prepare data for training and testing
time_step = 4  # Number of time steps (months in this case)
X, y = create_dataset(scaled_data, time_step)
X = X.reshape(X.shape[0], X.shape[1], 1)

# Step 7: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Step 8: Define a model-building function using SGD optimizer
def build_model(hp):
    model = Sequential()
    
    model.add(LSTM(units=hp.Int('units_1', min_value=50, max_value=1500, step=75), 
                   return_sequences=True, input_shape=(X_train.shape[1], 1)))
    
    model.add(Dropout(rate=hp.Float('dropout_1', min_value=0.3, max_value=0.6, step=0.1)))
    
    model.add(LSTM(units=hp.Int('units_2', min_value=50, max_value=1500, step=75), 
                   return_sequences=False))
    
    model.add(Dropout(rate=hp.Float('dropout_2', min_value=0.2, max_value=0.5, step=0.1)))
    
    model.add(Dense(units=1))

    # Use SGD with learning rate and momentum as hyperparameters
    model.compile(optimizer=SGD(learning_rate=hp.Float('learning_rate', min_value=1e-3, max_value=1e-2, sampling='LOG'),
                                momentum=hp.Float('momentum', min_value=0.1, max_value=0.9, step=0.1)), 
                  loss='mean_squared_error')
    
    return model

# Step 9: Initialize the tuner with early stopping and dynamic training duration
tuner = kt.Hyperband(build_model,
                     objective='val_loss',
                     max_epochs=1000,  # Limit number of epochs for faster tuning
                     factor=3,
                     directory='my_dir',
                     project_name='hyperparameter_tuning',
                     overwrite=True)

# Step 10: Perform the hyperparameter search
tuner.search(X_train, y_train, epochs=1000, batch_size=4, validation_data=(X_test, y_test), verbose=1)

# Step 11: Get the best model and hyperparameters
best_model = tuner.get_best_models(num_models=1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"Best Hyperparameters: {best_hyperparameters.values}")

# Step 12: Evaluate the best model on the test data
test_loss = best_model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")

# Step 13: Make predictions with the best model
predictions = best_model.predict(X_test)

# Step 14: Inverse transform the predictions and actual values
predictions = scaler.inverse_transform(predictions)
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Step 15: Visualize the results
plt.figure(figsize=(10, 6))
plt.plot(y_test_actual, color='blue', label='Actual Sales')
plt.plot(predictions, color='red', label='Predicted Sales')
plt.title('Sales Forecasting using Optimized LSTM')
plt.xlabel('Time')
plt.ylabel('Sales')
plt.legend()
plt.show()

# Step 16: Calculate evaluation metrics
mae = mean_absolute_error(y_test_actual, predictions)
mse = mean_squared_error(y_test_actual, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_actual, predictions)

print(f"Optimized Mean Absolute Error (MAE): {mae}")
print(f"Optimized Mean Squared Error (MSE): {mse}")
print(f"Optimized Root Mean Squared Error (RMSE): {rmse}")
print(f"Optimized R-squared (R²): {r2}")
# Out:
# Trial 114 Complete [00h 00m 04s]
# val_loss: 0.11946447938680649
#
# Best val_loss So Far: 0.001938999630510807
# Total elapsed time: 00h 26m 04s
#
# Search: Running Trial #115
#
# Value             |Best Value So Far |Hyperparameter
# 1025              |875               |units_1
# 0.4               |0.5               |dropout_1
# 1475              |1025              |units_2
# 0.2               |0.3               |dropout_2
# 0.006504          |0.0011378         |learning_rate
# 0.6               |0.1               |momentum
# 2                 |2                 |tuner/epochs
# 0                 |0                 |tuner/initial_epoch
# 6                 |6                 |tuner/bracket
# 0                 |0                 |tuner/round
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 86
#      77 tuner = kt.Hyperband(build_model,
#      78                      objective='val_loss',
#      79                      max_epochs=1000,  # Limit number of epochs for faster tuning
#    (...)
#      82                      project_name='hyperparameter_tuning',
#      83                      overwrite=True)
#      85 # Step 10: Perform the hyperparameter search
# ---> 86 tuner.search(X_train, y_train, epochs=1000, batch_size=4, validation_data=(X_test, y_test), verbose=1)
#      88 # Step 11: Get the best model and hyperparameters
#      89 best_model = tuner.get_best_models(num_models=1)[0]
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/base_tuner.py:234, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     231         continue
#     233     self.on_trial_begin(trial)
# --> 234     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235     self.on_trial_end(trial)
#     236 self.on_search_end()
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/base_tuner.py:274, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273     try:
# --> 274         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275         trial.status = trial_module.TrialStatus.COMPLETED
#     276         return
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/base_tuner.py:239, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     238 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241         self.oracle.objective.name
#     242     ):
#     243         # The oracle is updated by calling `self.oracle.update_trial()` in
#     244         # `Tuner.run_trial()`. For backward compatibility, we support this
#     245         # use case. No further action needed in this case.
#     246         warnings.warn(
#     247             "The use case of calling "
#     248             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     254             stacklevel=2,
#     255         )
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/tuners/hyperband.py:427, in Hyperband.run_trial(self, trial, *fit_args, **fit_kwargs)
#     425     fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     426     fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 427 return super().run_trial(trial, *fit_args, **fit_kwargs)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/tuner.py:232, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     214 """For AutoKeras to override.
#     215
#     216 DO NOT REMOVE this function. AutoKeras overrides the function to tune
#    (...)
#     229     The fit history.
#     230 """
#     231 hp = trial.hyperparameters
# --> 232 model = self._try_build(hp)
#     233 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     235 # Save the build config for model loading later.
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/tuner.py:164, in Tuner._try_build(self, hp)
#     161 keras.backend.clear_session()
#     162 gc.collect()
# --> 164 model = self._build_hypermodel(hp)
#     165 # Stop if `build()` does not return a valid model.
#     166 if not isinstance(model, keras.models.Model):
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/tuners/hyperband.py:430, in Hyperband._build_hypermodel(self, hp)
#     429 def _build_hypermodel(self, hp):
# --> 430     model = super()._build_hypermodel(hp)
#     431     if "tuner/trial_id" in hp.values:
#     432         trial_id = hp.values["tuner/trial_id"]
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras_tuner/src/engine/tuner.py:155, in Tuner._build_hypermodel(self, hp)
#     153 def _build_hypermodel(self, hp):
#     154     with maybe_distribute(self.distribution_strategy):
# --> 155         model = self.hypermodel.build(hp)
#     156         self._override_compile_args(model)
#     157         return model
#
# Cell In[12], line 62, in build_model(hp)
#      57 model.add(LSTM(units=hp.Int('units_1', min_value=50, max_value=1500, step=75),
#      58                return_sequences=True, input_shape=(X_train.shape[1], 1)))
#      60 model.add(Dropout(rate=hp.Float('dropout_1', min_value=0.3, max_value=0.6, step=0.1)))
# ---> 62 model.add(LSTM(units=hp.Int('units_2', min_value=50, max_value=1500, step=75),
#      63                return_sequences=False))
#      65 model.add(Dropout(rate=hp.Float('dropout_2', min_value=0.2, max_value=0.5, step=0.1)))
#      67 model.add(Dense(units=1))
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/trackable/base.py:204, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     202 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203 try:
# --> 204   result = method(self, *args, **kwargs)
#     205 finally:
#     206   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/engine/sequential.py:236, in Sequential.add(self, layer)
#     231         self._has_explicit_input_shape = True
#     233 elif self.outputs:
#     234     # If the model is being built continuously on top of an input layer:
#     235     # refresh its output.
# --> 236     output_tensor = layer(self.outputs[0])
#     237     if len(tf.nest.flatten(output_tensor)) != 1:
#     238         raise ValueError(SINGLE_LAYER_OUTPUT_ERROR_MSG)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/layers/rnn/base_rnn.py:556, in RNN.__call__(self, inputs, initial_state, constants, **kwargs)
#     551 inputs, initial_state, constants = rnn_utils.standardize_args(
#     552     inputs, initial_state, constants, self._num_constants
#     553 )
#     555 if initial_state is None and constants is None:
# --> 556     return super().__call__(inputs, **kwargs)
#     558 # If any of `initial_state` or `constants` are specified and are Keras
#     559 # tensors, then add them to the inputs and temporarily modify the
#     560 # input_spec to include them.
#     562 additional_inputs = []
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/engine/base_layer.py:1063, in Layer.__call__(self, *args, **kwargs)
#    1055 # Functional Model construction mode is invoked when `Layer`s are called
#    1056 # on symbolic `KerasTensor`s, i.e.:
#    1057 # >> inputs = tf.keras.Input(10)
#    1058 # >> outputs = MyLayer()(inputs)  # Functional construction mode.
#    1059 # >> model = tf.keras.Model(inputs, outputs)
#    1060 if _in_functional_construction_mode(
#    1061     self, inputs, args, kwargs, input_list
#    1062 ):
# -> 1063     return self._functional_construction_call(
#    1064         inputs, args, kwargs, input_list
#    1065     )
#    1067 # Maintains info about the `Layer.call` stack.
#    1068 call_context = base_layer_utils.call_context()
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/engine/base_layer.py:2603, in Layer._functional_construction_call(self, inputs, args, kwargs, input_list)
#    2597 with call_context.enter(
#    2598     layer=self, inputs=inputs, build_graph=True, training=training_value
#    2599 ):
#    2600     # Check input assumptions set after layer building, e.g. input
#    2601     # shape.
#    2602     try:
# -> 2603         outputs = self._keras_tensor_symbolic_call(
#    2604             inputs, input_masks, args, kwargs
#    2605         )
#    2606     except TypeError as e:
#    2607         if "DictWrapper" in str(e):
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/engine/base_layer.py:2449, in Layer._keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#    2445     return tf.nest.map_structure(
#    2446         keras_tensor.KerasTensor, output_signature
#    2447     )
#    2448 else:
# -> 2449     return self._infer_output_signature(
#    2450         inputs, args, kwargs, input_masks
#    2451     )
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/engine/base_layer.py:2506, in Layer._infer_output_signature(self, inputs, args, kwargs, input_masks)
#    2498 with backend.name_scope(self._name_scope()):
#    2499     with autocast_variable.enable_auto_cast_variables(
#    2500         self._compute_dtype_object
#    2501     ):
#    (...)
#    2504         # TODO(kaftan): do we maybe_build here, or have we already
#    2505         # done it?
# -> 2506         self._maybe_build(inputs)
#    2507         inputs = self._maybe_cast_inputs(inputs)
#    2508         outputs = call_fn(inputs, *args, **kwargs)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/engine/base_layer.py:3035, in Layer._maybe_build(self, inputs)
#    3030 if not hasattr(self.build, "_is_default"):
#    3031     # Any setup work performed only once should happen in an
#    3032     # `init_scope` to avoid creating symbolic Tensors that will
#    3033     # later pollute any eager operations.
#    3034     with tf_utils.maybe_init_scope(self):
# -> 3035         self.build(input_shapes)
#    3036 # We must set also ensure that the layer is marked as built, and the
#    3037 # build shape is stored since user defined build functions may not
#    3038 # be calling `super.build()`
#    3039 Layer.build(self, input_shapes)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/layers/rnn/base_rnn.py:461, in RNN.build(self, input_shape)
#     459 if isinstance(self.cell, base_layer.Layer) and not self.cell.built:
#     460     with backend.name_scope(self.cell.name):
# --> 461         self.cell.build(step_input_shape)
#     462         self.cell.built = True
#     464 # set or validate state_spec
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/utils/tf_utils.py:371, in shape_type_conversion.<locals>.wrapper(instance, input_shape)
#     369 if input_shape is not None:
#     370     input_shape = convert_shapes(input_shape, to_tuples=True)
# --> 371 output_shape = fn(instance, input_shape)
#     372 # Return shapes from `fn` as TensorShapes.
#     373 if output_shape is not None:
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/layers/rnn/lstm.py:199, in LSTMCell.build(self, input_shape)
#     190 input_dim = input_shape[-1]
#     191 self.kernel = self.add_weight(
#     192     shape=(input_dim, self.units * 4),
#     193     name="kernel",
#    (...)
#     197     caching_device=default_caching_device,
#     198 )
# --> 199 self.recurrent_kernel = self.add_weight(
#     200     shape=(self.units, self.units * 4),
#     201     name="recurrent_kernel",
#     202     initializer=self.recurrent_initializer,
#     203     regularizer=self.recurrent_regularizer,
#     204     constraint=self.recurrent_constraint,
#     205     caching_device=default_caching_device,
#     206 )
#     208 if self.use_bias:
#     209     if self.unit_forget_bias:
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/engine/base_layer.py:712, in Layer.add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, use_resource, synchronization, aggregation, **kwargs)
#     709 if layout:
#     710     getter = functools.partial(getter, layout=layout)
# --> 712 variable = self._add_variable_with_custom_getter(
#     713     name=name,
#     714     shape=shape,
#     715     # TODO(allenl): a `make_variable` equivalent should be added as a
#     716     # `Trackable` method.
#     717     getter=getter,
#     718     # Manage errors in Layer rather than Trackable.
#     719     overwrite=True,
#     720     initializer=initializer,
#     721     dtype=dtype,
#     722     constraint=constraint,
#     723     trainable=trainable,
#     724     use_resource=use_resource,
#     725     collections=collections_arg,
#     726     synchronization=synchronization,
#     727     aggregation=aggregation,
#     728     caching_device=caching_device,
#     729 )
#     730 if regularizer is not None:
#     731     # TODO(fchollet): in the future, this should be handled at the
#     732     # level of variable creation, and weight regularization losses
#     733     # should be variable attributes.
#     734     name_in_scope = variable.name[: variable.name.find(":")]
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/trackable/base.py:488, in Trackable._add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     478   if (checkpoint_initializer is not None and
#     479       not (isinstance(initializer, CheckpointInitialValueCallable) and
#     480            (initializer.restore_uid > checkpoint_initializer.restore_uid))):
#    (...)
#     485     # then we'll catch that when we call _track_trackable. So this is
#     486     # "best effort" to set the initializer with the highest restore UID.
#     487     initializer = checkpoint_initializer
# --> 488 new_variable = getter(
#     489     name=name,
#     490     shape=shape,
#     491     dtype=dtype,
#     492     initializer=initializer,
#     493     **kwargs_for_getter)
#     495 # If we set an initializer and the variable processed it, tracking will not
#     496 # assign again. It will add this variable to our dependencies, and if there
#     497 # is a non-trivial restoration queued, it will handle that. This also
#     498 # handles slot variables.
#     499 if not overwrite or isinstance(new_variable, Trackable):
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/engine/base_layer_utils.py:137, in make_variable(name, shape, dtype, initializer, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner, layout, experimental_enable_variable_lifting)
#     130     use_resource = True
#     132 if layout is None:
#     133     # In theory, in `use_resource` is True and `collections` is empty
#     134     # (that is to say, in TF2), we can use tf.Variable.
#     135     # However, this breaks legacy (Estimator) checkpoints because
#     136     # it changes variable names. Remove this when V1 is fully deprecated.
# --> 137     return tf1.Variable(
#     138         initial_value=init_val,
#     139         name=name,
#     140         trainable=trainable,
#     141         caching_device=caching_device,
#     142         dtype=variable_dtype,
#     143         validate_shape=validate_shape,
#     144         constraint=constraint,
#     145         use_resource=use_resource,
#     146         collections=collections,
#     147         synchronization=synchronization,
#     148         aggregation=aggregation,
#     149         shape=variable_shape if variable_shape else None,
#     150         experimental_enable_variable_lifting=experimental_enable_variable_lifting,  # noqa: E501
#     151     )
#     152 else:
#     153     return dtensor.DVariable(
#     154         initial_value=init_val,
#     155         name=name,
#    (...)
#     164         shape=variable_shape if variable_shape else None,
#     165     )
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/ops/variables.py:194, in VariableMetaclass.__call__(cls, *args, **kwargs)
#     191 @traceback_utils.filter_traceback
#     192 def __call__(cls, *args, **kwargs):
#     193   if hasattr(cls, "_variable_call") and callable(cls._variable_call):
# --> 194     variable_call = cls._variable_call(*args, **kwargs)
#     195     if variable_call is not None:
#     196       return variable_call
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/ops/variable_v1.py:305, in VariableV1._variable_call(cls, initial_value, trainable, validate_shape, caching_device, name, variable_def, dtype, import_scope, constraint, synchronization, aggregation, shape, experimental_enable_variable_lifting, expected_shape, collections, use_resource, **kwargs)
#     303 if aggregation is None:
#     304   aggregation = variables.VariableAggregation.NONE
# --> 305 return previous_getter(
#     306     initial_value=initial_value,
#     307     trainable=trainable,
#     308     validate_shape=validate_shape,
#     309     caching_device=caching_device,
#     310     name=name,
#     311     variable_def=variable_def,
#     312     dtype=dtype,
#     313     import_scope=import_scope,
#     314     constraint=constraint,
#     315     synchronization=synchronization,
#     316     aggregation=aggregation,
#     317     shape=shape,
#     318     experimental_enable_variable_lifting=experimental_enable_variable_lifting,
#     319     expected_shape=expected_shape,
#     320     collections=collections,
#     321     use_resource=use_resource,
#     322 )
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/ops/variable_v1.py:298, in VariableV1._variable_call.<locals>.<lambda>(**kwargs)
#     296 if cls is not VariableV1:
#     297   return None
# --> 298 previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#     299 for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     300   previous_getter = variables._make_getter(getter, previous_getter)  # pylint: disable=protected-access
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/ops/ref_variable.py:70, in default_variable_creator(next_creator, **kwargs)
#      68 if use_resource:
#      69   distribute_strategy = kwargs.get("distribute_strategy", None)
# ---> 70   return resource_variable_ops.ResourceVariable(
#      71       initial_value=initial_value,
#      72       trainable=trainable,
#      73       collections=collections,
#      74       validate_shape=validate_shape,
#      75       caching_device=caching_device,
#      76       name=name,
#      77       dtype=dtype,
#      78       constraint=constraint,
#      79       variable_def=variable_def,
#      80       import_scope=import_scope,
#      81       distribute_strategy=distribute_strategy,
#      82       synchronization=synchronization,
#      83       aggregation=aggregation,
#      84       shape=shape)
#      85 else:
#      86   return RefVariable(
#      87       initial_value=initial_value,
#      88       trainable=trainable,
#    (...)
#      99       aggregation=aggregation,
#     100       shape=shape)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/ops/variables.py:197, in VariableMetaclass.__call__(cls, *args, **kwargs)
#     195   if variable_call is not None:
#     196     return variable_call
# --> 197 return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1810, in ResourceVariable.__init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape, handle, experimental_enable_variable_lifting)
#    1805   self._init_from_handle(trainable=trainable,
#    1806                          shape=shape,
#    1807                          dtype=dtype,
#    1808                          handle=handle)
#    1809 else:
# -> 1810   self._init_from_args(
#    1811       initial_value=initial_value,
#    1812       trainable=trainable,
#    1813       collections=collections,
#    1814       caching_device=caching_device,
#    1815       name=name,
#    1816       dtype=dtype,
#    1817       constraint=constraint,
#    1818       synchronization=synchronization,
#    1819       aggregation=aggregation,
#    1820       shape=shape,
#    1821       distribute_strategy=distribute_strategy,
#    1822       validate_shape=validate_shape,
#    1823       experimental_enable_variable_lifting=experimental_enable_variable_lifting,
#    1824       )
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1994, in ResourceVariable._init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape, validate_shape, experimental_enable_variable_lifting)
#    1992 with ops.name_scope("Initializer"), device_context_manager(None):
#    1993   if init_from_fn:
# -> 1994     initial_value = initial_value()
#    1995   if isinstance(initial_value, trackable.CheckpointInitialValue):
#    1996     self._maybe_initialize_trackable()
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/initializers/initializers.py:760, in Orthogonal.__call__(self, shape, dtype, **kwargs)
#     756     _ensure_keras_seeded()
#     757     return utils.call_with_layout(
#     758         self._generate_init_val, layout, shape=shape, dtype=dtype
#     759     )
# --> 760 return self._generate_init_val(shape, dtype)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/keras/src/initializers/initializers.py:774, in Orthogonal._generate_init_val(self, shape, dtype)
#     772 a = self._random_generator.random_normal(flat_shape, dtype=dtype)
#     773 # Compute the qr factorization
# --> 774 q, r = tf.linalg.qr(a, full_matrices=False)
#     775 # Make Q uniform
#     776 d = tf.linalg.tensor_diag_part(r)
#
# File ~/FarmWise/tf-env/venv/lib/python3.8/site-packages/tensorflow/python/ops/gen_linalg_ops.py:2134, in qr(input, full_matrices, name)
#    2132 if tld.is_eager:
#    2133   try:
# -> 2134     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    2135       _ctx, "Qr", name, input, "full_matrices", full_matrices)
#    2136     _result = _QrOutput._make(_result)
#    2137     return _result
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Conv1D, MaxPooling1D, Flatten
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Step 1: Import the merged data
merged_data = pd.read_csv('merged_food_market_data.csv')

# Check the first few rows to understand the structure of the data
print(merged_data.head())

# Step 2: Handle missing values (if any)
merged_data.dropna(inplace=True)  # Remove missing values, or you can use fillna() for filling

# Step 3: If necessary, create a 'Date' column if not already present
if 'Date' not in merged_data.columns:
    merged_data['Date'] = pd.to_datetime(merged_data['Month'] + ' ' + merged_data['Year'].astype(str))

# Step 4: Select the column to predict
column_to_predict = 'Grocery stores sales million nominal U.S. dollars with taxes and tips'

if column_to_predict not in merged_data.columns:
    raise KeyError(f"The column '{column_to_predict}' is not in the dataset!")

data = merged_data[[column_to_predict]]

# Step 5: Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Step 6: Create the dataset for LSTM
def create_dataset(data, time_step=12):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:(i + time_step), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

# Prepare data for training and testing
time_step = 12  # Number of time steps (months in this case)
X, y = create_dataset(scaled_data, time_step)
X = X.reshape(X.shape[0], X.shape[1], 1)

# Step 7: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Step 8: Define a model-building function using CNN + LSTM
def build_cnn_lstm_model():
    model = Sequential()
    
    # Add CNN layers
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.2))
    
    # Add LSTM layer
    model.add(LSTM(units=100, return_sequences=False))
    
    # Output layer
    model.add(Dense(units=1))

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
    
    return model

# Step 9: Build and train the model
model = build_cnn_lstm_model()
history = model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), verbose=1)

# Step 10: Evaluate the model
test_loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")

# Step 11: Make predictions with the trained model
predictions = model.predict(X_test)

# Step 12: Inverse transform the predictions and actual values
predictions = scaler.inverse_transform(predictions)
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Step 13: Visualize the results
plt.figure(figsize=(10, 6))
plt.plot(y_test_actual, color='blue', label='Actual Sales')
plt.plot(predictions, color='red', label='Predicted Sales')
plt.title('Sales Forecasting using CNN + LSTM Model')
plt.xlabel('Time')
plt.ylabel('Sales')
plt.legend()
plt.show()

# Step 14: Calculate evaluation metrics
mae = mean_absolute_error(y_test_actual, predictions)
mse = mean_squared_error(y_test_actual, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_actual, predictions)

print(f"Optimized Mean Absolute Error (MAE): {mae}")
print(f"Optimized Mean Squared Error (MSE): {mse}")
print(f"Optimized Root Mean Squared Error (RMSE): {rmse}")
print(f"Optimized R-squared (R²): {r2}")
# Out:
#    Year      Month  \
# 0  2024   November
# 1  2024    October
# 2  2024  September
# 3  2024     August
# 4  2024       July
#
#    Food at home sales million nominal U.S. dollars with taxes and tips  \
# 0                                           95656.09
# 1                                           93264.84
# 2                                           88347.26
# 3                                           93574.33
# 4                                           92725.62
#
#    Food away from home sales million nominal U.S. dollars with taxes and tips  \
# 0                                          114435.81
# 1                                          117611.72
# 2                                          113183.13
# 3                                          120947.75
# 4                                          118376.29
#
#    Total food sales million nominal U.S. dollars with taxes and tips  \
# 0                                          210091.91
# 1                                          210876.56
# 2                                          201530.38
# 3                                          214522.08
# 4                                          211101.91
#
#    Food at home sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                           36217.51
# 1                                           35286.00
# 2                                           33472.50
# 3                                           35610.85
# 4                                           35260.13
#
#    Food away from home sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                           37323.76
# 1                                           38467.11
# 2                                           37106.51
# 3                                           39786.59
# 4                                           39042.41
#
#    Total food sales million constant 1988 U.S. dollars with taxes and tips_x  \
# 0                                           73541.27
# 1                                           73753.11
# 2                                           70579.02
# 3                                           75397.44
# 4                                           74302.53
#
#    Grocery stores sales million nominal U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Warehouse clubs and supercenters sales million nominal U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Grocery stores sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Warehouse clubs and supercenters sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Other food at home sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Total food at home sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Full-service restaurants sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Limited-service restaurants sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Other food away from home sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Total food away from home sales million constant 1988 U.S. dollars with taxes and tips  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Total food sales million constant 1988 U.S. dollars with taxes and tips_y  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#          Date
# 0  2024-11-01
# 1  2024-10-01
# 2  2024-09-01
# 3  2024-08-01
# 4  2024-07-01
#
# [5 rows x 27 columns]
# Epoch 1/50
# 16/16 [==============================] - 2s 30ms/step - loss: 0.0327 - val_loss: 0.0070
# Epoch 2/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0070 - val_loss: 0.0061
# Epoch 3/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0020
# Epoch 4/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 5/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0020
# Epoch 6/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0015
# Epoch 7/50
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 8/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 9/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 0.0014
# Epoch 10/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 11/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 12/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 13/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 14/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 15/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 16/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 17/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 18/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0015
# Epoch 19/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 20/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 21/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 22/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 23/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 24/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 25/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 26/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 27/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 28/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 29/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 30/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 31/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 32/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 33/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 34/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 35/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 36/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 37/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 38/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 39/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 40/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 41/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 42/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 43/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 44/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 45/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 46/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 47/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 48/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 49/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 50/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0015
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0015
# Test Loss: 0.0015458790585398674
# 2/2 [==============================] - 0s 2ms/step
# Optimized Mean Absolute Error (MAE): 946.3148214285715
# Optimized Mean Squared Error (MSE): 1535170.0713315029
# Optimized Root Mean Squared Error (RMSE): 1239.0198026389662
# Optimized R-squared (R²): 0.18745150233861851

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Conv1D, MaxPooling1D, Flatten
from sklearn.model_selection import train_test_split
import keras_tuner as kt
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Step 1: Import the merged data (use your actual data file)
merged_data = pd.read_csv('merged_food_market_data.csv')

# Check the first few rows to understand the structure of the data
print(merged_data.head())

# Step 2: Handle missing values (if any)
merged_data.dropna(inplace=True)  # Remove missing values

# Step 3: If necessary, create a 'Date' column if not already present
if 'Date' not in merged_data.columns:
    merged_data['Date'] = pd.to_datetime(merged_data['Month'] + ' ' + merged_data['Year'].astype(str))

# Step 4: Select the column to predict
column_to_predict = 'Grocery stores sales million nominal U.S. dollars with taxes and tips'

if column_to_predict not in merged_data.columns:
    raise KeyError(f"The column '{column_to_predict}' is not in the dataset!")

data = merged_data[[column_to_predict]]

# Step 5: Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Step 6: Create the dataset for LSTM + CNN
def create_dataset(data, time_step=12):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:(i + time_step), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

# Prepare data for training and testing
time_step = 12  # Number of time steps (months in this case)
X, y = create_dataset(scaled_data, time_step)
X = X.reshape(X.shape[0], X.shape[1], 1)

# Step 7: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Step 8: Define a model-building function using CNN + LSTM and hyperparameters for both
def build_model(hp):
    model = Sequential()

    # CNN layer (1D Convolutional layer)
    model.add(Conv1D(filters=hp.Int('filters', min_value=48, max_value=64, step=16),
                     kernel_size=hp.Int('kernel_size', min_value=3, max_value=7, step=1),
                     activation='relu', input_shape=(X_train.shape[1], 1)))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(rate=hp.Float('dropout_cnn', min_value=0.2, max_value=0.5, step=0.1)))

    # LSTM layer
    model.add(LSTM(units=hp.Int('lstm_units', min_value=50, max_value=150, step=25), 
                   return_sequences=False))
    model.add(Dropout(rate=hp.Float('dropout_lstm', min_value=0.3, max_value=0.6, step=0.1)))
    
    # Dense output layer
    model.add(Dense(units=1))

    # Use Adam optimizer with learning rate hyperparameter
    model.compile(optimizer=Adam(learning_rate=hp.Float('learning_rate', min_value=1e-5, max_value=1e-2, sampling='LOG')),
                  loss='mean_squared_error')

    return model

# Step 9: Initialize the tuner with early stopping and dynamic training duration
tuner = kt.Hyperband(build_model,
                     objective='val_loss',
                     max_epochs=1000,  # Limit number of epochs for faster tuning
                     factor=4,
                     directory='my_dir',
                     project_name='lstm_cnn_hyperparameter_tuning',
                     overwrite=True)

# Step 10: Perform the hyperparameter search
tuner.search(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# Step 11: Get the best model and hyperparameters
best_model = tuner.get_best_models(num_models=1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"Best Hyperparameters: {best_hyperparameters.values}")

# Step 12: Evaluate the best model on the test data
test_loss = best_model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")

# Step 13: Make predictions with the best model
predictions = best_model.predict(X_test)

# Step 14: Inverse transform the predictions and actual values
predictions = scaler.inverse_transform(predictions)
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Step 15: Visualize the results
plt.figure(figsize=(10, 6))
plt.plot(y_test_actual, color='blue', label='Actual Sales')
plt.plot(predictions, color='red', label='Predicted Sales')
plt.title('Sales Forecasting using Optimized LSTM + CNN')
plt.xlabel('Time')
plt.ylabel('Sales')
plt.legend()
plt.show()

# Step 16: Calculate evaluation metrics
mae = mean_absolute_error(y_test_actual, predictions)
mse = mean_squared_error(y_test_actual, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_actual, predictions)

print(f"Optimized Mean Absolute Error (MAE): {mae}")
print(f"Optimized Mean Squared Error (MSE): {mse}")
print(f"Optimized Root Mean Squared Error (RMSE): {rmse}")
print(f"Optimized R-squared (R²): {r2}")
# Out:
# Trial 147 Complete [00h 00m 03s]
# val_loss: 0.0023974315263330936
#
# Best val_loss So Far: 0.001459433464333415
# Total elapsed time: 00h 06m 31s
#
# Search: Running Trial #148
#
# Value             |Best Value So Far |Hyperparameter
# 64                |48                |filters
# 5                 |3                 |kernel_size
# 0.2               |0.4               |dropout_cnn
# 100               |125               |lstm_units
# 0.5               |0.5               |dropout_lstm
# 0.00027674        |0.0018077         |learning_rate
# 4                 |4                 |tuner/epochs
# 0                 |0                 |tuner/initial_epoch
# 4                 |4                 |tuner/bracket
# 0                 |0                 |tuner/round
#
# Epoch 1/4

# %%
ls
# Out:
# 'Analysis of Constant Dollar Expenditures.ipynb'
#  combining_log.txt
#  constant_dollar_expenditures_no_taxes_tips.csv
#  dash.py
# 'Food Expenditures.ipynb'
#  food_expenditures_source_funds.csv
#  Food_Market.ipynb
#  history_log.txt
#  merged_food_market_data.csv
# 'monthly_sales by outlet.csv'
#  monthly_sales.csv
#  Monthly_sales.ipynb
#  my_dir/
#  nominal_expenditures_no_taxes_tips.csv
#  normalized_food_expenditures.csv
#  résumé_SGBD.docx
#  Untitled1.ipynb
#  Untitled2.ipynb
#  Untitled3.ipynb
#  Untitled4.ipynb
#  Untitled.ipynb

# %%
pwd
# Out:
# '/home/iyed/FarmWise/tf-env/venv/food_market'

# %%
merged_data.head()
# Out:
#     Year      Month  \
# 11  2023   December
# 12  2023   November
# 13  2023    October
# 14  2023  September
# 15  2023     August
#
#     Food at home sales million nominal U.S. dollars with taxes and tips  \
# 11                                           99928.52
# 12                                           92102.15
# 13                                           89396.82
# 14                                           87172.37
# 15                                           90775.52
#
#     Food away from home sales million nominal U.S. dollars with taxes and tips  \
# 11                                          116537.31
# 12                                          107247.69
# 13                                          111500.33
# 14                                          110354.03
# 15                                          113539.74
#
#     Total food sales million nominal U.S. dollars with taxes and tips  \
# 11                                          216465.83
# 12                                          199349.84
# 13                                          200897.16
# 14                                          197526.41
# 15                                          204315.27
#
#     Food at home sales million constant 1988 U.S. dollars with taxes and tips  \
# 11                                           38455.36
# 12                                           35417.95
# 13                                           34201.21
# 14                                           33444.88
# 15                                           34851.25
#
#     Food away from home sales million constant 1988 U.S. dollars with taxes and tips  \
# 11                                           39267.09
# 12                                           36255.38
# 13                                           37856.77
# 14                                           37607.60
# 15                                           38845.93
#
#     Total food sales million constant 1988 U.S. dollars with taxes and tips_x  \
# 11                                           77722.45
# 12                                           71673.33
# 13                                           72057.98
# 14                                           71052.48
# 15                                           73697.17
#
#     Grocery stores sales million nominal U.S. dollars with taxes and tips  \
# 11                                           51628.40
# 12                                           49031.77
# 13                                           47988.36
# 14                                           47388.03
# 15                                           48744.54
#
#     Warehouse clubs and supercenters sales million nominal U.S. dollars with taxes and tips  \
# 11                                           25028.96
# 12                                           21150.10
# 13                                           20387.58
# 14                                           19592.93
# 15                                           21026.62
#
#     ...  \
# 11  ...
# 12  ...
# 13  ...
# 14  ...
# 15  ...
#
#     Grocery stores sales million constant 1988 U.S. dollars with taxes and tips  \
# 11                                           19867.56
# 12                                           18854.70
# 13                                           18358.77
# 14                                           18180.59
# 15                                           18713.88
#
#     Warehouse clubs and supercenters sales million constant 1988 U.S. dollars with taxes and tips  \
# 11                                            9632.17
# 12                                            8133.55
# 13                                            7800.08
# 14                                            7517.34
# 15                                            8072.96
#
#     Other food at home sales million constant 1988 U.S. dollars with taxes and tips  \
# 11                                            8955.63
# 12                                            8429.70
# 13                                            8042.36
# 14                                            7746.95
# 15                                            8064.40
#
#     Total food at home sales million constant 1988 U.S. dollars with taxes and tips  \
# 11                                           38455.36
# 12                                           35417.95
# 13                                           34201.21
# 14                                           33444.88
# 15                                           34851.25
#
#     Full-service restaurants sales million constant 1988 U.S. dollars with taxes and tips  \
# 11                                           15974.15
# 12                                           14025.89
# 13                                           14604.36
# 14                                           14472.93
# 15                                           14930.25
#
#     Limited-service restaurants sales million constant 1988 U.S. dollars with taxes and tips  \
# 11                                           14989.14
# 12                                           14164.12
# 13                                           14975.65
# 14                                           14840.42
# 15                                           15471.54
#
#     Other food away from home sales million constant 1988 U.S. dollars with taxes and tips  \
# 11                                            8303.80
# 12                                            8065.38
# 13                                            8276.76
# 14                                            8294.25
# 15                                            8444.14
#
#     Total food away from home sales million constant 1988 U.S. dollars with taxes and tips  \
# 11                                           39267.09
# 12                                           36255.39
# 13                                           37856.77
# 14                                           37607.60
# 15                                           38845.93
#
#     Total food sales million constant 1988 U.S. dollars with taxes and tips_y  \
# 11                                           77722.45
# 12                                           71673.34
# 13                                           72057.98
# 14                                           71052.48
# 15                                           73697.17
#
#           Date
# 11  2023-12-01
# 12  2023-11-01
# 13  2023-10-01
# 14  2023-09-01
# 15  2023-08-01
#
# [5 rows x 27 columns]
